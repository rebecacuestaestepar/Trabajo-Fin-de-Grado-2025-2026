# %% [markdown]
# ### Openpyxl
#
# Primero vamos a trastear con openpyxl para ver cómo puedo sacar los datos del excel

# %%
from openpyxl import load_workbook

wb = load_workbook("HORARIOS VENA(Curso 24-25).xlsx")

# Sacamos los nombres de las hojas que hay en el excel
print(wb.sheetnames)
# Out:
# ['GIEIA', 'GIM', 'GIOI', 'D_GIM-GIEIA ', 'GII (primero)', 'GII ', 'MINFORM', 'MINDUST', 'MDURAB', 'MESO', 'ASIGNATURAS', 'Aulas', 'GIS', 'Hoja1']

# %%
# Analizamos el horario para el grado en ingeniería informática
gii=wb.worksheets[5]

for row in gii.iter_rows():
    for cell in row:
        print(cell.coordinate, cell.value)
# Out:
# A1 =VLOOKUP(A4,ASIGNATURAS!$A$2:$D$151, 3, FALSE)
# B1 None
# C1 None
# D1 None
# E1 None
# F1 None
# G1 None
# H1 None
# I1 None
# J1 None
# K1 None
# L1 None
# M1 None
# N1 None
# O1 None
# P1 None
# Q1 None
# R1 None
# S1 None
# T1 None
# U1 None
# V1 None
# W1 None
# X1 None
# Y1 None
# Z1 None
# AA1 None
# AB1 None
# AC1 None
# AD1 None
# AE1 None
# AF1 None
# AG1 None
# AH1 None
# AI1 None
# AJ1 None
# AK1 None
# AL1 None
# AM1 None
# AN1 None
# AO1 None
# AP1 ='GII (primero)'!AT34
# AQ1 None
# AR1 None
# AS1 None
# AT1 None
# AU1 None
# AV1 None
# AW1 None
# AX1 None
# AY1 None
# AZ1 None
# BA1 None
# BB1 None
# BC1 None
# BD1 None
# BE1 None
# BF1 None
# BG1 None
# BH1 None
# BI1 None
# BJ1 None
# BK1 None
# BL1 None
# BM1 None
# BN1 None
# BO1 None
# BP1 None
# BQ1 None
# BR1 None
# BS1 None
# BT1 None
# BU1 None
# BV1 None
# BW1 None
# BX1 None
# BY1 None
# BZ1 None
# CA1 None
# CB1 None
# A2 =VLOOKUP(A4,ASIGNATURAS!$A$2:$D$151, 2, FALSE)
# B2 None
# C2 None
# D2 None
# ...

# %%
for row in gii.iter_rows(values_only=True):
    print(row)
# Out:
# ('=VLOOKUP(A4,ASIGNATURAS!$A$2:$D$151, 3, FALSE)', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, "='GII (primero)'!AT34", None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ...

# %%
for merged in gii.merged_cells.ranges:
    print(merged)

# Me devuelve el rango de las celdas mergeadas pero no en orden
# Out:
# AJ123:AJ125
# O122:O125
# N123:N125
# Z111:AB114
# AF120:AO120
# AF121:AO121
# AP114:AY114
# L114:U114
# AP113:AY113
# AF113:AO113
# AF118:AO118
# AF119:AO119
# AP116:AY116
# AP117:AY117
# AF116:AO116
# AF117:AO117
# A124:A125
# A107:A108
# B107:K107
# L107:U107
# V107:AE107
# Y111:Y114
# X112:X114
# L111:U111
# A111:A112
# B111:K111
# A109:A110
# C122:C125
# B123:B125
# B114:K114
# A118:A119
# V116:AE116
# V117:AE117
# L116:U116
# L117:U117
# B116:K116
# B117:K117
# A116:A117
# B115:K115
# L115:U115
# T40:T42
# AB48:AB50
# AF48:AF50
# V38:AE38
# W24:Z24
# AP34:AY34
# A60:G60
# A120:A121
# A122:A123
# V115:AE115
# AF115:AO115
# AP107:AY107
# B108:K108
# L108:U108
# V108:AE108
# AF108:AO108
# AP108:AY108
# B109:K109
# L109:U109
# V109:AE109
# AP109:AY109
# B110:K110
# L110:U110
# V110:AE110
# R72:R74
# I71:I74
# H72:H74
# AI71:AI74
# A66:AO66
# AO71:AO74
# AK71:AK74
# AJ72:AJ74
# AA54:AY54
# AF72:AF74
# AH72:AH74
# AN72:AN74
# AL72:AL74
# AA55:AY55
# A180:G180
# AP185:AY185
# ...

# %%
cell=gii["B5"]
print(cell.fill.start_color.rgb)

# El color no es un string, y por tanto, no devuelve el color de la celda
# Out:
# Values must be of type <class 'str'>

# %%
cell2=gii["B6"]
cell2.alignment.textRotation

# La rotación me la devuelve de manera correcta
# 0 -> Texto horizontal
# 90 -> Texto vertical
# Out:
# 90

# %%
"""
Ordenamos las celdas mergeadas, para poder extraer bien los datos
"""

from openpyxl.utils.cell import coordinate_from_string, column_index_from_string

def sort_key_range(rng):
    start = str(rng).split(":")[0]  
    col_letters, row = coordinate_from_string(start) 
    return (row, column_index_from_string(col_letters))

merged_sorted = sorted(gii.merged_cells.ranges, key=sort_key_range)

for r in merged_sorted:
    print(r)
# Out:
# A1:AO1
# AP1:AY1
# A2:AO2
# AP2:AY3
# A3:AO3
# B5:K5
# L5:U5
# V5:AE5
# AF5:AO5
# AP5:AY5
# A6:A7
# C6:C9
# E6:E9
# G6:G9
# I6:I9
# K6:K9
# M6:M9
# O6:O9
# Q6:Q9
# U6:U9
# W6:W9
# Y6:Y9
# AA6:AA9
# AC6:AC9
# AG6:AG9
# AI6:AI9
# AM6:AM9
# AO6:AO9
# AQ6:AQ9
# AS6:AS9
# AU6:AU9
# AW6:AW9
# AY6:AY9
# B7:B9
# D7:D9
# F7:F9
# H7:H9
# J7:J9
# L7:L9
# N7:N9
# P7:P9
# T7:T9
# V7:V9
# X7:X9
# Z7:Z9
# AB7:AB9
# AF7:AF9
# AH7:AH9
# AL7:AL9
# AN7:AN9
# AP7:AP9
# AR7:AR9
# AT7:AT9
# AV7:AV9
# AX7:AX9
# A8:A9
# A10:A11
# B10:G10
# H10:J10
# L10:Q10
# R10:T10
# V10:AA10
# AB10:AD10
# AF10:AK10
# AL10:AN10
# AP10:AU10
# AV10:AX10
# B11:G11
# H11:J11
# L11:Q11
# R11:T11
# V11:AA11
# AB11:AD11
# AF11:AK11
# AL11:AN11
# AP11:AU11
# AV11:AX11
# A12:A13
# B12:G12
# H12:J12
# L12:Q12
# R12:T12
# V12:AA12
# AB12:AD12
# AF12:AK12
# AL12:AN12
# AP12:AU12
# AV12:AX12
# B13:G13
# H13:J13
# L13:Q13
# R13:T13
# V13:AA13
# AB13:AD13
# AF13:AK13
# AL13:AN13
# AP13:AU13
# AV13:AX13
# A14:A15
# C14:C17
# E14:E17
# ...

# %%
# Quiero saber exactamente qué tipo es el color que hay en el excel
# Investigamos los diferentes tipos para verqué me devuelve para cada uno de ellos

c = cell.fill.start_color
print("type:", c.type)         
print("rgb:", c.rgb)
print("theme:", c.theme)
print("indexed:", c.indexed)

print(cell2.fill.start_color.theme)
# Out:
# type: theme
# rgb: Values must be of type <class 'str'>
# theme: 5
# indexed: Values must be of type <class 'int'>
# 8

# %%
print(cell.fill.start_color.theme)
print(cell2.fill.start_color.theme)

cell3 = gii["B10"]
cell4 = gii["B11"]

print(cell3.fill.start_color.theme)
print(cell4.fill.start_color.theme)

goi = wb.worksheets[2]
cell5 = goi["N119"]
cell6 = goi["L113"]
cell7 = goi["AA113"]

print(cell5.fill.start_color.theme)
print(cell6.fill.start_color.theme)
print(cell7.fill.start_color.theme)


gii2 = wb.worksheets[4]
cell8 = gii2["H10"]
cell9 = gii2["B12"]
cell10 = gii2["B7"]
cell10 = gii2["B6"]
print(f"Grupo práctico: {cell9.fill.start_color.rgb}")
print(f"Grupo teórico: {cell10.fill.start_color.theme}")
print(cell8.fill.start_color.theme)
print(cell8.fill.start_color.type)
print(cell8.fill.start_color.rgb)
# Out:
# Values must be of type <class 'int'>
# 8
# 9
# 7
# 7
# 6
# 7
# Grupo práctico: 00000000
# Grupo teórico: 9
# Values must be of type <class 'int'>
# rgb
# FFF1FA78

# %%
c2 = cell2.fill.start_color
print("type:", c2.type)         
print("rgb:", c2.rgb)
print("theme:", c2.theme)
print("indexed:", c2.indexed)

# El color es un tema de la hoja, theme
# Out:
# type: theme
# rgb: Values must be of type <class 'str'>
# theme: 8
# indexed: Values must be of type <class 'int'>

# %%
import re

# Hacemos la función que va a clasificar qué tipo de contenido es el de la celda mediante expr regulares
def clasificar_celda(cell):
    valor = cell.value

    if valor is None:
        return

    texto = str(valor).strip()

    if texto.upper() in ["LUNES", "MARTES", "MIÉRCOLES", "JUEVES", "VIERNES"]:
        return ("DIA", texto)

    if re.match(r"^\d{1,2}:\d{2}$", texto):
        return ("HORA", texto)

    if texto.upper() == "HORA":
        return ("comienzo_tabla")

    if re.match(r"d{3}", texto):
        return ("grupo_practico", texto)

    if re.match(r"d{1}", texto):
        return ("grupo_teoricos", texto)

    return ("TEXTO_GENERAL", texto)

# %%
for row in gii.iter_rows():
    for cell in row:
        token = clasificar_celda(cell)
        if token[0] != "VACIA":
            print(cell.coordinate, token)
# Out:
# A1 ('TEXTO_GENERAL', '=VLOOKUP(A4,ASIGNATURAS!$A$2:$D$151, 3, FALSE)')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
#       2 for cell in row:
#       3     token = clasificar_celda(cell)
# ----> 4     if token[0] != "VACIA":
#       5         print(cell.coordinate, token)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
for r in merged_sorted:
    inicio, fin = str(r).split(":")
    
    valor = gii[inicio].value
    
    print("Rango:", r)
    print("Inicio:", inicio)
    print("Fin:", fin)
    print("Valor:", valor)
    print("-" * 40)
# Out:
# Rango: A1:AO1
# Inicio: A1
# Fin: AO1
# Valor: =VLOOKUP(A4,ASIGNATURAS!$A$2:$D$151, 3, FALSE)
# ----------------------------------------
# Rango: AP1:AY1
# Inicio: AP1
# Fin: AY1
# Valor: ='GII (primero)'!AT34
# ----------------------------------------
# Rango: A2:AO2
# Inicio: A2
# Fin: AO2
# Valor: =VLOOKUP(A4,ASIGNATURAS!$A$2:$D$151, 2, FALSE)
# ----------------------------------------
# Rango: AP2:AY3
# Inicio: AP2
# Fin: AY3
# Valor: Aula 51A1
# ----------------------------------------
# Rango: A3:AO3
# Inicio: A3
# Fin: AO3
# Valor: Grupo: TARDE
# ----------------------------------------
# Rango: B5:K5
# Inicio: B5
# Fin: K5
# Valor: LUNES
# ----------------------------------------
# Rango: L5:U5
# Inicio: L5
# Fin: U5
# Valor: MARTES
# ----------------------------------------
# Rango: V5:AE5
# Inicio: V5
# Fin: AE5
# Valor: MIÉRCOLES
# ----------------------------------------
# Rango: AF5:AO5
# Inicio: AF5
# Fin: AO5
# Valor: JUEVES
# ----------------------------------------
# ...

# %% [markdown]
# ### COMENZAMOS A TRATAR DE HACER LA EXTRACCIÓN DE DATOS

# %%
class Clase:
    def __init__(self, asig, cod_asig, grupo, aula, hora_inicio, hora_fin, dia, tipo):
        self.asig = asig
        self.cod_asig = cod_asig
        self.grupo = grupo
        self.aula = aula
        self.hora_inicio = hora_inicio
        self.hora_fin = hora_fin
        self.dia = dia
        self.tipo = tipo
        
    def __repr__(self):
        return f"[{self.dia} | {self.hora_inicio}-{self.hora_fin}] {self.tipo} - {self.asig} (Gr:{self.grupo}) en {self.aula}"

    def __eq__(self, other):
        if isinstance(other, Clase):
            return (self.asig == other.asig and
                   self.cod_asig == other.cod_asig and
                   self.grupo == other.grupo and
                   self.aula == other.aula and
                   self.hora_inicio == other.hora_inicio and
                   self.hora_fin == other.hora_fin and
                   self.dia == other.dia and
                   self.tipo == other.tipo)
        return False

# %%
from openpyxl import load_workbook

wb = load_workbook("HORARIOS VENA(Curso 24-25).xlsx")

# Sacamos los nombres de las hojas que hay en el excel
print(wb.sheetnames)
# Out:
# C:\Users\usuario\anaconda3\envs\gi\lib\site-packages\openpyxl\reader\excel.py:237: UserWarning: Data Validation extension is not supported and will be removed
#   ws_parser.bind_all()
# ['GIEIA', 'GIM', 'GIOI', 'D_GIM-GIEIA', 'GII (primero)', 'GII', 'MINFORM', 'MINDUST', 'MDURAB', 'MESO', 'ASIGNATURAS', 'Aulas', 'GIS', 'Hoja1', 'Reglas', 'Grados']

# %%
import re

def clasificar_celda2(cell):
    valor = cell.value

    if valor is None:
        return

    texto = str(valor).strip()

    if texto.upper() in ["LUNES", "MARTES", "MIÉRCOLES", "JUEVES", "VIERNES"]:
        return ("DIA", texto)

    if re.match(r"^\d{1,2}:\d{2}$", texto):
        return ("HORA", texto)

    if texto.upper() == "HORA":
        return ("comienzo_tabla")

    if re.match(r"(d{3})", texto):
        return ("grupo_practico", texto)

    if re.match(r"d{1}", texto):
        return ("grupo_teoricos", texto)

    if texto.upper() == "CODIGO":
        return("COL_CODIGO")

    if re.match(r"\d{4}-?E?", texto):
        return ("CODIGO_ASIG", texto)

    if texto.upper() == "NOMBRE ABREVIADO":
        return ("comienzo_asignaturas")

    return ("TEXTO_GENERAL", texto)

# %%
import re

class ConfigurarHorario:

    # Expresiones regulares
    HORA = re.compile(r"(?i)^\s*hora\s*$")
    TRAMO = re.compile(r"^\s*\d{1,2}:\d{2}\s*-\s*\d{1,2}:\d{2}\s*$")

    NOMBRE_ABREVIADO = re.compile(r"(?i)^\s*nombre abreviado\s*$")

    AULA = re.compile(r"(?i)(aula|lab|sala|lb)")
    GRUPO_PRACTICO = re.compile(r"^\s*\(?\d{3}\)?\s*$")
    GRUPO_TEORICO = re.compile(r"^\s*\d{1,2}\s*$")   # Mirar si tiene que ser dos por el grupo teórico de Inglés (80)

    CODIGO = re.compile(r"^\s*\d{4}-?E?\s*$")

    COL_CODIGO = re.compile(r"(?i)^\s*codigo\s*$")

    # Literales
    DIAS_SEMANA = ["LUNES", "MARTES", "MIÉRCOLES", "JUEVES", "VIERNES"]

# %%
# Esta función va a analizar le valor de la celda y va a devolver un token
def clasificar_celda(valor_celda):
    if valor_celda is None:
        return ("VACIA", None)

    texto = str(valor_celda).strip()

    if ConfigurarHorario.HORA.match(texto):
        return ("COMIENZO_TABLA", texto)
    if ConfigurarHorario.NOMBRE_ABREVIADO.match(texto):
        return ("COMIENZO_TABLA_ASIGNATURAS", texto)
    if texto.upper() in ConfigurarHorario.DIAS_SEMANA:
        return ("DIA_SEMANA", texto.upper())

    if ConfigurarHorario.TRAMO.match(texto):
        return ("TRAMO_HORARIO", texto)
    
    if ConfigurarHorario.GRUPO_TEORICO.match(texto):
        return ("GRUPO_TEORICO", texto)

    if ConfigurarHorario.GRUPO_PRACTICO.match(texto):
        valor_limpio = texto.replace("(", "").replace(")", "")
        return ("GRUPO_PRACTICO", valor_limpio)

    if ConfigurarHorario.AULA.search(texto):
        return ("AULA", texto)

    if ConfigurarHorario.COL_CODIGO.match(texto):
        return ("COL_CODIGO", texto)

    if ConfigurarHorario.CODIGO.match(texto):
        return ("CODIGO_ASIG", texto)
        
    if texto.isupper() and texto not in ConfigurarHorario.DIAS_SEMANA:
        return ("ABREV_ASIG", texto)

    if not ConfigurarHorario.AULA.search(texto) and not ConfigurarHorario.GRUPO_TEORICO.match(texto) and not ConfigurarHorario.GRUPO_PRACTICO.match(texto) and not None:
        return ("ABREV_ASIG", texto)

    return ("TEXTO_GENERAL", texto)

# %%
def extraer_columnas_dias(ws, fila_inicio):
    dias_rangos = {}

    for col in range(2, ws.max_column + 1):
        celda = ws.cell(row=fila_inicio, column=col)
        tipo, valor = clasificar_celda(celda.value)
        if tipo == "DIA_SEMANA":
            col_inicio = col
            col_fin = col

            # Comprobamos si es una celda mergeada
            for rango_merge in ws.merged_cells.ranges:
                if celda.coordinate in rango_merge:
                    col_inicio = rango_merge.min_col
                    col_fin = rango_merge.max_col
                    break
            dias_rangos[valor] = {
                "col_inicio": col_inicio,
                "col_fin": col_fin
            }
        return dias_rangos

# %%
# Creamos una función que crea el diccionario de celdas mergeadas O(n)
def celdas_mergeadas(ws):
    mapa_merge = {}
    for rango in ws.merged_cells.ranges:
        # rango.start.cell te da directamente la celda superior izquierda
        coord_origen = rango.start_cell.coordinate

        mapa_merge[coord_origen] = {
            "col_inicio": rango.min_col,
            "col_fin": rango.max_col,
            "fila_inicio": rango.min_row,
            "fila_fin": rango.max_row
        }

    return mapa_merge

# %%
def extraer_leyenda_asignaturas(ws, mapa_merge, diccionario_cod):
    diccionario_asignaturas = {}
    leyendo_tabla = False
    
    for fila in range(1, ws.max_row + 1):
        col = 1
        celda = ws.cell(row = fila, column = col)
        tipo, valor = clasificar_celda(celda.value)

        if tipo == "COMIENZO_TABLA_ASIGNATURAS":
            leyendo_tabla = True
            continue

        if leyendo_tabla:
            if valor == None or not str(valor).isupper():
                leyendo_tabla = False
                continue

            if celda.coordinate in mapa_merge:
                col_nombre_completo = mapa_merge[celda.coordinate]["col_fin"] + 1
            else:
                col_nombre_completo = col + 1

            celda_nombre_completo = ws.cell(row = fila, column = col_nombre_completo)

            if celda_nombre_completo.coordinate in mapa_merge:
                col_codigo = mapa_merge[celda_nombre_completo.coordinate]["col_fin"] + 1
            else:
                col_codigo = col_nombre_completo + 1

            celda_codigo = ws.cell(row=fila, column = col_codigo)
            tipo_c, valor_c = clasificar_celda(celda_codigo.value)

            if tipo_c == "CODIGO_ASIG":
                abrev_asig = diccionario_cod[valor_c]
            
                diccionario_asignaturas[abrev_asig] = valor_c
    return diccionario_asignaturas

# %%
def extraer_columnas_dias2(ws, fila_inicio, mapa_merge):
    dias_rangos = {}

    for col in range(2, ws.max_column + 1):
        celda = ws.cell(row=fila_inicio, column=col)
        tipo, valor = clasificar_celda(celda.value)

        if tipo == "DIA_SEMANA":
            print(valor)
            coord = celda.coordinate

            if coord in mapa_merge:
                limites = mapa_merge[coord]
                col_inicio = limites["col_inicio"]
                col_fin = limites["col_fin"]
            else:
                col_inicio = col
                col_fin = col

            dias_rangos[valor] = {
                "col_inicio": col_inicio,
                "col_fin": col_fin
            }
            
            if valor.upper() == "VIERNES":
                print("Condición de parada de los días")
                break
                
    return dias_rangos

# %%
def extraer_filas_tramos(ws, fila_inicio, mapa_merge):
    tramos_horarios = []
    fila_actual = fila_inicio + 1
    contador = 0

    while fila_actual <= ws.max_row:
        celda = ws.cell(row=fila_actual, column = 1)
        tipo, valor = clasificar_celda(celda.value)

        if tipo == "TRAMO_HORARIO":
            coord = celda.coordinate

            if coord in mapa_merge:
                f_inicio = mapa_merge[coord]["fila_inicio"]
                f_fin = mapa_merge[coord]["fila_fin"]
            else:
                f_inicio = fila_actual
                f_fin = fila_actual

            tramos_horarios.append({
                "hora": valor,
                "fila_inicio": f_inicio,
                "fila_fin": f_fin
            })

            fila_actual = f_fin
        else:
            contador+=1
            if contador > 0:
                print("Condición de parada tramos horarios")
                break
                
        fila_actual += 1
                
    return tramos_horarios

# %%
def extraer_codigo_asignaturas(ws):
    diccionario_cod_asig = {}
    fila_inicio = 0
    columna_codigo = 0
    for fila in range(1, ws.max_row + 1):
        for col in range(1, ws.max_column + 1):
            celda = ws.cell(row=fila, column=col)
            tipo, valor = clasificar_celda(celda.value)

            if tipo == "COL_CODIGO":
                columna_codigo = col
                fila_inicio = fila + 1
                break
        if columna_codigo != 0:
            break

    if columna_codigo != 0:
        for fila in range(fila_inicio, ws.max_row + 1):
            celda_cod = ws.cell(row=fila, column=columna_codigo)
            tipo_cod, valor_cod = clasificar_celda(celda_cod.value)
            if tipo_cod == "CODIGO_ASIG":
                celda_asig = ws.cell(row=fila, column=columna_codigo+2)
                tipo_asig, valor_asig = clasificar_celda(celda_asig.value)
    
                if tipo_asig == "ABREV_ASIG":
                    diccionario_cod_asig[valor_cod] = valor_asig
    return diccionario_cod_asig

# %% [markdown]
# ### Temas de los diferentes grupos
#
# - Grupos prácticos:
#     - Azul: theme 8,4
#     - Verde: theme 6
#     - Amarillo verdos: rgb FFF1FA78
#     - Otro azul: rgb 00000000
#
# - Grupos teóricos:
#     - Carne: theme 9
#     - Beis: theme 2
#     - Morado: theme 7

# %%
def extraer_teoricas(ws, fila_inicio, fila_fin, col_actual, mapa_merge, celdas_visitadas, asignaturas):
    celda_derecha = ws.cell(row=fila_actual, column = mapa_merge[coord]["col_fin"] + 1)
    tipo_d, valor_d = clasificar_celda(celda_derecha.value)
                        
    if tipo_d == "AULA":
        print("Celda derecha")
        print(f"AULA: {valor_d}, color: {celda_derecha.fill.start_color.theme}")
        celdas_visitadas.add(celda_derecha.coordinate)
        
        #Buscamos el grupo teórico
        if celda_derecha.coordinate in mapa_merge:
            col_grupo = mapa_merge[celda_derecha.coordinate]["col_fin"]+1
        else:
            col_grupo = celda_derecha.column + 1
                                
        celda_grupo = ws.cell(row=fila_actual, column=col_grupo)
        tipo_g, valor_g = clasificar_celda(celda_grupo.value)
                            
        if tipo_g == "GRUPO_TEORICO":
            print(f"Grupo teórico: {valor_g}")
            celdas_visitadas.add(celda_grupo.coordinate)

            col = limites["col_inicio"]
            #if celda_grupo.coordinate in mapa_merge:
                #siguiente_col = mapa_merge[celda_grupo.coordinate]["col_fin"]+1
            #else:
                #siguiente_col = celda_grupo.column + 1
            if fila_actual != tramo["fila_fin"]:
                siguiente_col = col - 1
                fila_actual += 1 
                                                           
                            
    else:
        celda_abajo = ws.cell(row = fila_actual + 1, column = col)
        tipo_a, valor_a = clasificar_celda(celda_abajo.value)
        print(f"AULA: {valor_a}, color: {celda_abajo.fill.start_color.theme}")
        celdas_visitadas.add(celda_abajo.coordinate)

# %%
def extraer_teoricas2(ws, fila_inicio, fila_fin, col_actual, mapa_merge, celdas_visitadas, tabla, asignaturas, clases):
    dia = calcular_dia(tabla["mapa_dias"], col_actual)
    col_salto = col_actual + 1
    for f in range(fila_inicio, fila_fin + 1):
        valor_aula= "Aula 0"
        valor_a = "Aula 0"
        cond = False
        celda_asig = ws.cell(row=f, column=col_actual)
        tipo_asig, valor_asig = clasificar_celda(celda_asig.value)
        
        if tipo_asig != "ABREV_ASIG" or celda_asig.coordinate in celdas_visitadas:
            continue
            
        print(f"\n[CLASE TEÓRICA] Asignatura: {valor_asig}, {asignaturas[valor_asig]}")
        celdas_visitadas.add(celda_asig.coordinate)

        fila_ini_clase = celda_asig.row
        
        if celda_asig.coordinate in mapa_merge:
            col_aula = mapa_merge[celda_asig.coordinate]["col_fin"] + 1
            fila_fin_clase = mapa_merge[celda_asig.coordinate]["fila_fin"]
        else:
            col_aula = col_actual + 1
            fila_fin_clase = fila_ini_clase

        hora_inicio, hora_fin = calcular_horario_clase(tabla["lista_tramos"], fila_ini_clase, fila_fin_clase)
        print(f"Día: {dia}")
        print(f"Horario: {hora_inicio} - {hora_fin}")
            
        celda_aula = ws.cell(row=f, column=col_aula)
        tipo_aula, valor_aula = clasificar_celda(celda_aula.value)
        
        if tipo_aula == "AULA":
            cond, num_aulas, aulas = extraer_aulas_2(valor_aula)
            #print(f"AULA: {valor_aula}, color: {celda_aula.fill.start_color.theme}")
            celdas_visitadas.add(celda_aula.coordinate)
            
            if celda_aula.coordinate in mapa_merge:
                col_grupo = mapa_merge[celda_aula.coordinate]["col_fin"] + 1
            else:
                col_grupo = col_aula + 1
                
            celda_grupo = ws.cell(row=f, column=col_grupo)
            tipo_grupo, valor_grupo = clasificar_celda(celda_grupo.value)
            
            if tipo_grupo == "GRUPO_TEORICO":
                print(f"Grupo teórico: {valor_grupo}")
                celdas_visitadas.add(celda_grupo.coordinate)
                if cond:
                    for aula in aulas.values():
                        print(f"Aula: {aula}")
                        nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                        clases.append(nueva_clase)
                else:
                    nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=valor_aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                    clases.append(nueva_clase)
                    print(f"Aula: {valor_aula}")
                if celda_grupo.coordinate in mapa_merge:
                    nuevo_salto = mapa_merge[celda_grupo.coordinate]["col_fin"] + 1
                else:
                    nuevo_salto = col_grupo + 1
                    
                if nuevo_salto > col_salto:
                    col_salto = nuevo_salto
            else:
                if cond:
                    for aula in aulas.values():
                        if celda_asig.fill.start_color.theme == 9:
                            valor_grupo = "1"
                            print(f"Grupo teórico: {valor_grupo}")
                            nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                            clases.append(nueva_clase)
                        elif celda_asig.fill.start_color.theme == 7:
                            valor_grupo = "80"
                            print(f"Grupo teórico: {valor_grupo}")
                            nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                            clases.append(nueva_clase)
                else:
                    if celda_asig.fill.start_color.theme == 9:
                        valor_grupo = "1"
                        print(f"Grupo teórico: {valor_grupo}")
                        nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=valor_aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                        clases.append(nueva_clase)
                    elif celda_asig.fill.start_color.theme == 7:
                        valor_grupo = "80"
                        print(f"Grupo teórico: {valor_grupo}")
                        nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=valor_aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                        clases.append(nueva_clase)
        else:
            celda_abajo = ws.cell(row=f + 1, column=col_actual)
            tipo_a, valor_a = clasificar_celda(celda_abajo.value)
            if tipo_a == "AULA":
                cond, num_aulas, aulas = extraer_aulas_2(valor_a)
                celdas_visitadas.add(celda_abajo.coordinate)
            else:
                valor_a = "Aula 0"
                cond = False
            

            if celda_asig.fill.start_color.theme == 7:
                valor_grupo = "80"
                if cond:
                    for aula in aulas.values():
                        print(f"Aula: {aula}")
                        print(f"Grupo teórico: {valor_grupo}")
                        nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                        clases.append(nueva_clase)
                else:
                    print(f"Grupo teórico: {valor_grupo}")
                    print(f"AULA: {valor_a}")
                    nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=valor_a, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                    clases.append(nueva_clase)
            elif celda_asig.fill.start_color.theme == 9:
                valor_grupo = "1"
                if cond:
                    for aula in aulas.values():
                        print(f"Aula: {aula}")
                        print(f"Grupo teórico: {valor_grupo}")
                        nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                        clases.append(nueva_clase)
                else:
                    print(f"Grupo teórico: {valor_grupo}")
                    print(f"AULA: {valor_a}")
                    nueva_clase = Clase(asig=valor_asig, cod_asig=asignaturas[valor_asig], grupo=valor_grupo, aula=valor_a, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="T")
                    clases.append(nueva_clase)
    return col_salto

# %%
def extraer_clase_practica_grupo2(ws, fila_actual, col_actual, mapa_merge, celdas_visitadas, tabla, asignaturas, clases):
    celda = ws.cell(row=fila_actual, column=col_actual)
    coord = celda.coordinate
    tipo, valor = clasificar_celda(celda.value) # 'valor' será el nombre del grupo
    print(f"CELDA: {coord}")
    
    dia = calcular_dia(tabla["mapa_dias"], col_actual)
    fila_ini_clase = celda.row

    celda_abajo = ws.cell(row=fila_actual + 1, column=col_actual)
    tipo_a, valor_a = clasificar_celda(celda_abajo.value)

    if tipo_a == "ABREV_ASIG":
        celdas_visitadas.add(celda_abajo.coordinate)
        
    if coord in mapa_merge:
        col_aula = mapa_merge[coord]["col_fin"] + 1
    else:
        col_aula = col_actual + 1
                                
    celda_derecha = ws.cell(row=fila_actual, column=col_aula)
    tipo_d, valor_d = clasificar_celda(celda_derecha.value)

    if celda_derecha.coordinate in mapa_merge:
        fila_fin_clase = mapa_merge[celda_derecha.coordinate]["fila_fin"]
        salto_col = mapa_merge[celda_derecha.coordinate]["col_fin"] + 1
    else:
        fila_fin_clase = fila_ini_clase
        salto_col = col_aula + 1

    hora_inicio, hora_fin = calcular_horario_clase(tabla["lista_tramos"], fila_ini_clase, fila_fin_clase)

    cond = False
    if tipo_d == "AULA":
        celdas_visitadas.add(celda_derecha.coordinate)
        cond, num_aulas, aulas = extraer_aulas_2(valor_d)
    elif valor_d is None:
        valor_d = "Aula 0"
        cond = False

    if cond:
        for aula in aulas.values():
            nueva_clase = Clase(asig=valor_a, cod_asig=asignaturas[valor_a], grupo=valor, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="P")
            clases.append(nueva_clase)
            print(f"[CLASE PRÁCTICA] Asignatura: {valor_a}")
            print(f"Día: {dia}")
            print(f"Horario: {hora_inicio} - {hora_fin}")
            print(f"Aula: {aula}")
            print(f"Grupo práctico: {valor}")
            print("")

    else:
        nueva_clase = Clase(asig=valor_a, cod_asig=asignaturas[valor_a], grupo=valor, aula=valor_d, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="P")
        nueva_clase = clases.append(nueva_clase)
        print(f"[CLASE PRÁCTICA] Asignatura: {valor_a}")
        print(f"Día: {dia}")
        print(f"Horario: {hora_inicio} - {hora_fin}")
        print(f"Aula: {valor_d}")
        print(f"Grupo práctico: {valor}")
        
    return salto_col

# %%
def extraer_practica_rotada90(ws, fila_actual, col_actual, mapa_merge, celdas_visitadas, tabla, asignaturas, clases):
    celda = ws.cell(row=fila_actual, column=col_actual)
    coord = celda.coordinate
    tipo, valor = clasificar_celda(celda.value) # 'valor' es la ABREV_ASIG
    
    dia = calcular_dia(tabla["mapa_dias"], col_actual)
    fila_ini_clase = celda.row 
    
    if coord in mapa_merge:
        col_grupo = mapa_merge[coord]["col_fin"] + 1
        fila_fin_clase = mapa_merge[coord]["fila_fin"]
    else:
        col_grupo = col_actual + 1
        fila_fin_clase = fila_ini_clase

    hora_inicio, hora_fin = calcular_horario_clase(tabla["lista_tramos"], fila_ini_clase, fila_fin_clase)
        
    celda_grupo = ws.cell(row=fila_actual, column=col_grupo)
    tipo_d, valor_d = clasificar_celda(celda_grupo.value)

    if tipo_d == "GRUPO_PRACTICO":
        celdas_visitadas.add(celda_grupo.coordinate)
        if celda_grupo.coordinate in mapa_merge:
            col_aula = mapa_merge[celda_grupo.coordinate]["col_fin"] + 1
        else:
            col_aula = col_grupo + 1  # CORRECCIÓN: Antes tenías 'col + 1'
    if celda.fill.start_color.theme == 7 and tipo_d != "GRUPO_PRACTICO":
        valor_d = "80"
        tipo = "T"
        if tipo_d == "AULA":
            col_aula = col_grupo
        else:
            col_aula = col_grupo + 1
    elif celda.fill.start_color.theme == 9 and tipo_d != "GRUPO_PRACTICO":
        print("Entro al segundo elif")
        valor_d = "1"
        tipo = "T"
        if tipo_d == "AULA":
            col_aula = col_grupo
        else:
            col_aula = col_grupo + 1
    else:
        print("Entro al else")
        if tipo_d == "AULA":
            col_aula = col_grupo
        else:
            col_aula = col_grupo + 1
        tipo = "P"

    celda_aula = ws.cell(row=fila_actual, column=col_aula)
    tipo_d2, valor_d2 = clasificar_celda(celda_aula.value)

    cond = False
    if tipo_d2 == "AULA":
        celdas_visitadas.add(celda_aula.coordinate)
        cond, num_aulas, aulas = extraer_aulas_2(valor_d2)
        
        if celda_aula.coordinate in mapa_merge:
            salto_col = mapa_merge[celda_aula.coordinate]["col_fin"] + 1
        else:
            salto_col = col_aula + 1
    else:
        if valor_d2 is None:
            valor_d2 = "Aula 0"
        salto_col = col_aula + 1 

    
    if cond:
        for aula in aulas.values():
            nueva_clase = Clase(asig=valor, cod_asig=asignaturas[valor], grupo=valor_d, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo=tipo)
            clases.append(nueva_clase)
            print(f"[CLASE PRÁCTICA] Asignatura: {valor}, {asignaturas[valor]}")
            print(f"Día: {dia}")
            print(f"Horario: {hora_inicio }- {hora_fin}")
            print(f"Aula: {aula}")
            print(f"Grupo práctico: {valor_d}")
            print("")
    else:
        nueva_clase = Clase(asig=valor, cod_asig=asignaturas[valor], grupo=valor_d, aula=valor_d2, hora_inicio=hora_inicio,hora_fin=hora_fin, dia=dia, tipo=tipo)
        clases.append(nueva_clase)
        print(f"[CLASE PRÁCTICA] Asignatura: {valor}, {asignaturas[valor]}")
        print(f"Día: {dia}")
        print(f"Horario: {hora_inicio} - {hora_fin}")
        print(f"Aula: {valor_d2}")
        print(f"Grupo práctico: {valor_d}")
        
    return salto_col

# %%
def extraer_practica_asig_rotacion0(ws, fila_actual, col_actual, mapa_merge, celdas_visitadas, tabla, asignaturas, clases):
    celda = ws.cell(row=fila_actual, column=col_actual)
    coord = celda.coordinate
    tipo, valor = clasificar_celda(celda.value) # 'valor' es la abreviatura de la asignatura
    
    dia = calcular_dia(tabla["mapa_dias"], col_actual)
    fila_ini_clase = celda.row

    if coord in mapa_merge:
        fila_aula = mapa_merge[coord]["fila_fin"] + 1
    else:
        fila_aula = fila_actual + 1
        
    celda_abajo = ws.cell(row=fila_aula, column=col_actual)
    tipo_a, valor_a = clasificar_celda(celda_abajo.value)

    cond = False
    if tipo_a == "AULA":
        cond, num_aulas, aulas = extraer_aulas_2(valor_a)
        celdas_visitadas.add(celda_abajo.coordinate)
    elif valor_a is None:
        valor_a = "Aula 0"
        cond = False

    if celda_abajo.coordinate in mapa_merge:
        fila_fin_clase = mapa_merge[celda_abajo.coordinate]["fila_fin"]
    else:
        fila_fin_clase = fila_ini_clase
        
    hora_inicio, hora_fin = calcular_horario_clase(tabla["lista_tramos"], fila_ini_clase, fila_fin_clase)

    if coord in mapa_merge:
        col_grupo = mapa_merge[coord]["col_fin"] + 1
    else:
        col_grupo = col_actual + 1
        
    celda_derecha = ws.cell(row=fila_actual, column=col_grupo)
    tipo_d, valor_d = clasificar_celda(celda_derecha.value)

    if tipo_d == "GRUPO_PRACTICO":
        celdas_visitadas.add(celda_derecha.coordinate)
        if celda_derecha.coordinate in mapa_merge:
            salto_col = mapa_merge[celda_derecha.coordinate]["col_fin"] + 1
        else:
            salto_col = col_grupo + 1
    else:
        valor_d = 101 
        salto_col = col_grupo 
    
    if cond:
        for aula in aulas.values():
            nueva_clase = Clase(asig=valor, cod_asig=asignaturas[valor], grupo=valor_d, aula=aula, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="P")
            clases.append(nueva_clase)
            print(f"[CLASE PRÁCTICA] Asignatura: {valor}, {asignaturas[valor]}")
            print(f"Día: {dia}")
            print(f"Horario: {hora_inicio} - {hora_fin}")
            print(f"Aula: {aula}")
            print(f"Grupo Práctico: {valor_d}, color: {celda_derecha.fill.start_color.theme}")
    else:
        nueva_clase =  Clase(asig=valor, cod_asig=asignaturas[valor], grupo=valor_d, aula=valor_a, hora_inicio=hora_inicio, hora_fin=hora_fin, dia=dia, tipo="P")
        clases.append(nueva_clase)
        print(f"[CLASE PRÁCTICA] Asignatura: {valor}, {asignaturas[valor]}")
        print(f"Día: {dia}")
        print(f"Horario: {hora_inicio} - {hora_fin}")
        print(f"Aula: {valor_a}")
        print(f"Grupo Práctico: {valor_d}, color: {celda_derecha.fill.start_color.theme}")
        
    return salto_col

# %%
def extraer_clases(ws, tabla, mapa_merge, asignaturas):
    clases = []


    celdas_visitadas = set()

    for dia, limites in tabla["mapa_dias"].items():
        for tramo in tabla["lista_tramos"]:
            #for fila_actual in range(tramo["fila_inicio"], tramo["fila_fin"] + 1):
            #for col in range(limites["col_inicio"], limites["col_fin"] + 1):
            fila_actual = tramo["fila_inicio"]
            contador=0
            col = limites["col_inicio"]
            while col <= limites["col_fin"]:
                celda = ws.cell(row=fila_actual, column=col)
                coord = celda.coordinate
                siguiente_col = col + 1
                if coord in celdas_visitadas:
                    col = siguiente_col
                    continue
                        
                tipo, valor = clasificar_celda(celda.value)
                    
                if tipo in ["GRUPO_PRACTICO", "GRUPO_TEORICO", "AULA", "ABREV_ASIG"]:
                    color_tema = celda.fill.start_color.theme
                    color_rgb = celda.fill.start_color.rgb
    
                    print("")
                        
                    if color_tema in [2,7,9] and tipo == "ABREV_ASIG" and celda.alignment.textRotation == 90:
                        siguiente_col = extraer_practica_rotada90(ws, fila_actual, col, mapa_merge, celdas_visitadas, tabla, asignaturas, clases)
    
                    elif color_tema in [2,7,9] and tipo == "ABREV_ASIG" and coord in mapa_merge:
                        siguiente_col = extraer_teoricas2(ws, tramo["fila_inicio"], tramo["fila_fin"], col, mapa_merge, celdas_visitadas, tabla, asignaturas, clases)
    
                                
                    elif (color_tema in [6,8] or color_rgb == "FFF1FA78") and tipo == "GRUPO_PRACTICO":
                        siguiente_col = extraer_clase_practica_grupo2(ws, fila_actual, col, mapa_merge, celdas_visitadas, tabla, asignaturas, clases)

                                
                    elif (color_tema in [6,8] or color_rgb == "FFF1FA78") and tipo == "ABREV_ASIG" and celda.alignment.textRotation == 90:
                        siguiente_col = extraer_practica_rotada90(ws, fila_actual, col, mapa_merge, celdas_visitadas, tabla, asignaturas, clases)

                                    
                    elif (color_tema in [6,8] or color_rgb == "FFF1FA78") and tipo == "ABREV_ASIG" and celda.alignment.textRotation == 0:
                        siguiente_col = extraer_practica_asig_rotacion0(ws, fila_actual, col, mapa_merge, celdas_visitadas, tabla, asignaturas, clases)

        
                    else:
                        print("")
                        print(f"TIPO: {tipo}, valor: {valor}, tema: {color_tema}, rgb: {color_rgb}")
                            
                    
                                 
                col = siguiente_col
        return clases

# %%
def calcular_horario_clase(lista_tramos, fila_inicio, fila_fin):
    hora_inicio = "00:00"
    hora_fin = "00:00"

    for tramo in lista_tramos:
        if tramo["fila_inicio"] <= fila_inicio <= tramo["fila_fin"]:
            hora_inicio = tramo["hora"].split("-")[0].strip()

        if tramo["fila_inicio"] <= fila_fin <= tramo["fila_fin"]:
            hora_fin = tramo["hora"].split("-")[1].strip()

    return hora_inicio, hora_fin

# %%
def calcular_dia(mapa_dias, col):
    dia = ""

    for d in mapa_dias:
        if mapa_dias[d]["col_inicio"] <= col <= mapa_dias[d]["col_fin"]:
            dia = d

    return dia

# %%
def extraer_aulas(valor):
    aula1 = ""
    aula2 = ""
    if "," in str(valor) or "/" in str(valor):
        aula1 = valor.split("/")[0].strip()
        aula2 = valor.split("/")[1].strip()

        return True, aula1, aula2
    return False, aula1, aula2

# %%
def extraer_aulas_2(valor):
    cont=0
    aulas={}
    for i, caracter in enumerate(valor):
        if caracter == "/":
            aulas[f"aula{cont}"] = valor.split("/")[cont].strip()
            cont+=1
            aulas[f"aula{cont}"] = valor.split("/")[cont].strip()

    if cont > 0:
        cond = True
    else:
        cond =  False
    return cond, cont + 1, aulas

# %%
cond, num_aulas, aulas = extraer_aulas_2("Aula Inf. 2B / Lab. Tecn. Mecánica / 32-A2")
print(f"Número de aulas encontradas: {num_aulas}")
print(f"Aulas:\n {aulas}")
print(f"Varias aulas: {cond}")
# Out:
# Número de aulas encontradas: 3
# Aulas:
#  {'aula0': 'Aula Inf. 2B', 'aula1': 'Lab. Tecn. Mecánica', 'aula2': '32-A2'}
# Varias aulas: True

# %%
"""
Función para escanear la hoja, que detecta las tablas de horarios y extrae las clases de cada una de ellas
"""
def escanear_hoja(ws, diccionario_cod):
    clases_hoja = []
    mapa_merge = celdas_mergeadas(ws)

    asignaturas = extraer_leyenda_asignaturas(ws, mapa_merge, diccionario_cod)

    print(asignaturas)
    
    fila_actual = 1
    max_row = ws.max_row
    
    while fila_actual <= max_row:
        celda = ws.cell(row=fila_actual, column = 1)
        tipo, valor = clasificar_celda(celda.value)
        
        if tipo == "COMIENZO_TABLA":
            #print("=========================")
            #print("He encontrado una tabla")
            #print("=========================")
            mapa_dias = extraer_columnas_dias2(ws, fila_actual, mapa_merge)
            lista_tramos = extraer_filas_tramos(ws, fila_actual, mapa_merge)
            
            tabla = {
                "mapa_dias": mapa_dias,
                "lista_tramos": lista_tramos
            }
            
            clases_tabla = extraer_clases(ws, tabla, mapa_merge, asignaturas)
            
            for clase in clases_tabla:
                clases_hoja.append(clase)
            
            if lista_tramos:
                fila_actual = lista_tramos[-1]["fila_fin"]
            
            #break
            
        fila_actual += 1
    
    return clases_hoja

# %%
def valida_extraccion(salida_real, salida_esperada):
    print("===========================")
    print("VALIDADOR DE OBJETOS 'CLASE'")
    print("===========================")

    clases_correctas = 0

    for clase_esperada in salida_esperada:
        if clase_esperada in salida_real:
            print(f"OK: {clase_esperada}")
            clases_correctas += 1
        else:
            print(f"ERROR: No se encontró la clase")
            print(f"Se esperaba: {clase_esperada}")
    print("\n=========================================")
    print(f"RESULTADO: {clases_correctas} de {len(salida_esperada)} clases correctas.")
    if clases_correctas == len(salida_esperada):
        print("FUNCIONA A LA PERFECCIÓN")
    print("=========================================")

# %%
def extraer_hojas_analizar(ws):
    fila_inicio = 2
    hojas = []
    col=1

    while fila_inicio <= ws.max_row:
        celda = ws.cell(row=fila_inicio, column=col)
        if celda.value == None:
            break
        hojas.append(celda.value)
        fila_inicio += 1
    return hojas

# %%
hojas_recorrer = extraer_hojas_analizar(wb.worksheets[-1])
print(f"Grados: {hojas_recorrer}")
# Out:
# Grados: ['GIEIA', 'GIM', 'GIOI', 'D_GIM-GIEIA', 'GII (primero)', 'GII']

# %%
diccionario_asignaturas = extraer_codigo_asignaturas(wb["ASIGNATURAS"])
hojas_recorrer = extraer_hojas_analizar(wb.worksheets[-1])

clases = []
for hoja in hojas_recorrer:
#for i in range(6):
    #ws = wb.worksheets[i]
    ws = wb[hoja]
    print(f"\n--- Procesando hoja: {ws.title} ---")
    clases_hoja = escanear_hoja(ws, diccionario_asignaturas)
    clases.extend(clases_hoja)

print(f"\nTotal de clases extraídas en todas las hojas: {len(clases)}")
print(f"{clases}")
# Out:
# --- Procesando hoja: GIEIA ---
# {'ALGEBRA': '6392', 'CALCULO': '6393', 'FISICA I': '6394', 'EXP. GRAFICA': '6395', 'INFORMATICA': '6396', 'MATERIALES': '6397', 'AMP. CALCULO': '6398', 'FISICA II': '6399', 'QUIMICA': '6400', 'ECONOMIA': '6401', 'TERMICA': '6402', 'E.C.N.': '6403', 'ING. ELECTRICA': '6404', 'ORG. PROD.': '6405', 'ERMAT': '6406', 'FLUIDOMECANICA': '6407', 'ELECTRONICA': '6408', 'MECANISMOS': '6409', 'AUTOMATISMOS': '6410', 'CIRCUITOS': '6411', 'ELECT. ANALOG.': '6412', 'ELECT. DIGITAL': '6413', 'REG. AUTOMAT.': '6414', 'SIST. ELECTRON.': '6415', 'MAQUINAS ELEC.': '6416', 'ELECT. POTENCIA': '6417', 'SIST. MICRO.': '6418', 'INSTR. ELECT.': '6419', 'CONTROL PROC.': '6420', 'PROD. Y FABRIC.': '6421', 'INFIND': '6422', 'OFICINA': '6423', 'ELECTRON. IND.': '6424', 'INST SOLARES': '6425', 'RENOVABLES': '6426', 'PREV. RIESGOS': '6427', 'INTEG S.E.': '6428', 'INSTAL. ELEC.': '6429', 'DAO': '6430', 'AUTIND': '6431', 'ROBOTICA': '6432'}
# LUNES
# MARTES
# MIÉRCOLES
# JUEVES
# ...

# %%
"""
Escaneo de momento solamente la hoja que quiero para ir probando el funcionamiento del extractor de clases.
"""
# GII(primero) -> 4
ws = wb.worksheets[3]
diccionario_asig = extraer_codigo_asignaturas(wb["ASIGNATURAS"])
escanear_hoja(ws, diccionario_asig)
# Out:
# {'CALCULO': '7711', 'ALGEBRA': '7712', 'FISICA I': '7713', 'QUIMICA': '7714', 'EXP. GRAFICA I': '7715', 'AMP. CALCULO': '7716', 'INFORMATICA': '7717', 'FISICA II': '7718', 'CIENCIA DE MATERIALES': '7719', 'ECONOMIA': '7720', 'EXP. GRAFICA II': '7721', 'ING. TERMICA I': '7722', 'ING. ELECTRICA': '7723', 'ERMAT I': '7724', 'E.C.N.': '7725', 'PRODUCCION': '7726', 'RENOVABLES': '7727', 'CIRCUITOS': '7728', 'FUND. ELECTRONICA': '7729', 'MECANISMOS': '7730', 'FLUIDOMECANICA': '7731', 'AUTOMATISMOS': '7732', 'MATERIALES': '7733', 'M ELECTRICAS': '7740', 'RESISTENCIA II': '7735', 'MECANISMOS II': '7736', 'ANALOGICA': '7737', 'DIGITAL': '7738', 'FABRICACION': '7739', 'TERMICA II': '7734', 'REGULACION': '7741', 'MICROS': '7742', 'D MAQUINAS I': '7743', 'TEC. MECANICA I': '7749', 'D MAQUINAS II': '7745', 'INSTRUMENTACION': '7746', 'ING. GRAFICA': '7747', 'SIST. ELECTRON.': '7748', 'POTENCIA': '7744', 'CONTROL PROC.': '7750', 'INSTALACIONES I': '7751', 'INF INDUSTRIAL': '7752', 'ESTRUCTURAS I': 
# ...

# %%
"Quitar valores sin tema"
"Añadir aulas, que  hay alguna clase que no tiene aula"
# Out:
# 'Añadir aulas, que  hay alguna clase que no tiene aula'

# %%
salida_esperada_gieia = [
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
    Clase(asig="FÍSICA I", grupo="1", aula="Aula 35-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="FÍSICA I", grupo="101", aula="Lab. Física", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="FÍSICA I", grupo="101", aula="Aula 42-A2", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="102", aula="Aula Inf. 1B", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="101", aula="Aula Inf. 1B", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 35-A2", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 35-A2", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 52-A2", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="102", aula="Lab 46-A1", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="EXP. GRAF.", grupo="1", aula="Aula 41-A2", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="EXPRESION GRAFICA", grupo="101", aula="Aula 53-A2 (CAD)", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="102", aula="Aula 41-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 35-A2", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="102", aula="Aula 35-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="102", aula="Aula 52-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="FISICA I", grupo="1", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 35-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),
    Clase(asig="INFORMATICA", grupo="101", aula="Lab 46-A1", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="FISICA I", grupo="102", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="FISICA I", grupo="102", aula="Aula 42-A2", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
          
    Clase(asig="QUIMICA", grupo="1", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
    Clase(asig="MATERIALES", grupo="1", aula="Aula 34-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="102", aula="Aula 21-A1", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="MATERIALES", grupo="1", aula="Aula 34-A2", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="101", aula="Aula 21-A1", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="MATERIALES", grupo="102", aula="Lab. Materiales", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 21-A1", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 21-A1", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="MATERIALES", grupo="101", aula="Lab. Materiales", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="CALCULO", grupo="102", aula="Aula 52-A2 (Inf.)", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="CALCULO", grupo="102", aula="36-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Lab. Química", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Aula 44-A2", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="AMP. CALCULO", grupo="1", aula="Aula 34-A2", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="FISICA II", grupo="102", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="FISICA II", grupo="102", aula="Aula 44-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="QUIMICA", grupo="102", aula="Lab. Química", hora_inicio="12:30", hora_fin="14:30", dia="JUEVES", tipo="P"),
    Clase(asig="QUIMICA", grupo="102", aula="Aula 44-A2", hora_inicio="12:30", hora_fin="14:30", dia="JUEVES", tipo="P"),
    Clase(asig="AMP.CALCULO", grupo="1", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 34-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),
    Clase(asig="FISICA II", grupo="101", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Aula 44-A2", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="101", aula="Aula 55-A2 (Inf.)", hora_inicio="12:30", hora_fin="14:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="101", aula="36-A2", hora_inicio="12:30", hora_fin="14:30", dia="VIERNES", tipo="P"),

    Clase(asig="ERMAT", grupo="101", aula="Aula 44-A2", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="ORG. PROD.", grupo="102", aula="Lab 24-A1", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="ORG. PROD.", grupo="1", aula="Aula 44-A2", hora_inicio="16:30", hora_fin="17:30", dia="LUNES", tipo="T"),
    Clase(asig="ERMAT", grupo="1", aula="Aula 44-A2", hora_inicio="17:30", hora_fin="18:30", dia="LUNES", tipo="T"),
    Clase(asig="TERMICA", grupo="1", aula="Aula 44-A2", hora_inicio="18:30", hora_fin="19:30", dia="LUNES", tipo="T"),
    Clase(asig="TERMICA", grupo="1", aula="Aula 44-A2", hora_inicio="19:30", hora_fin="20:30", dia="LUNES", tipo="T"),
    Clase(asig="TERMICA", grupo="101", aula="Aula Inf. 2B", hora_inicio="14:30", hora_fin="16:30", dia="MARTES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="102", aula="Lab. I. Eléctrica 1", hora_inicio="14:30", hora_fin="16:30", dia="MARTES", tipo="P"),
    Clase(asig="E.C.N.", grupo="1", aula="Aula 44-A2", hora_inicio="16:30", hora_fin="17:30", dia="MARTES", tipo="T"),
    Clase(asig="ING. ELECTRICA", grupo="1", aula="Aula 44-A2", hora_inicio="17:30", hora_fin="18:30", dia="MARTES", tipo="T"),
    Clase(asig="E.C.N.", grupo="102", aula="Aula 51-A2 (Inf.)", hora_inicio="18:30", hora_fin="20:30", dia="MARTES", tipo="P"),
    Clase(asig="ORG. PROD.", grupo="101", aula="Lab. 24-A1", hora_inicio="14:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ERMAT", grupo="102", aula="Aula 44-A2", hora_inicio="14:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ORG. PROD.", grupo="1", aula="Aula 44-A2", hora_inicio="16:30", hora_fin="17:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ERMAT", grupo="1", aula="Aula 44-A2", hora_inicio="17:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ING. ELECTRICA", grupo="101", aula="Lab. I. Eléctrica 1", hora_inicio="14:30", hora_fin="16:30", dia="JUEVES", tipo="P"),
    Clase(asig="TERMICA", grupo="102", aula="Aula Inf. 2B", hora_inicio="14:30", hora_fin="16:30", dia="JUEVES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="1", aula="Aula 44-A2", hora_inicio="16:30", hora_fin="17:30", dia="JUEVES", tipo="T"),
    Clase(asig="E.C.N.", grupo="1", aula="Aula 44-A2", hora_inicio="17:30", hora_fin="18:30", dia="JUEVES", tipo="T"),
    Clase(asig="E.C.N.", grupo="101", aula="Aula 51-A2", hora_inicio="18:30", hora_fin="20:30", dia="JUEVES", tipo="P"),

    Clase(asig="CIRCUITOS", grupo="101", aula="Lab. I. Eléctrica 1", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="AUTOMATISMOS", grupo="102", aula="Lab Automática 1", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="AUTOMATISMOS", grupo="1", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="17:30", dia="LUNES", tipo="T"),
    Clase(asig="CIRCUITOS", grupo="1", aula="Aula 35-A2", hora_inicio="17:30", hora_fin="18:30", dia="LUNES", tipo="T"),
    Clase(asig="FLUIDOMEC.", grupo="1", aula="Aula 35-A2", hora_inicio="18:30", hora_fin="19:30", dia="LUNES", tipo="T"),
    Clase(asig="FLUIDOMEC.", grupo="1", aula="Aula 35-A2", hora_inicio="19:30", hora_fin="20:30", dia="LUNES", tipo="T"),
    Clase(asig="MECANISMOS", grupo="101", aula="Aula 35-A2", hora_inicio="14:30", hora_fin="16:30", dia="MARTES", tipo="P"),
    Clase(asig="CIRCUITOS", grupo="102", aula="Lab. I. Eléctrica 1", hora_inicio="14:30", hora_fin="16:30", dia="MARTES", tipo="P"),
    Clase(asig="CIRCUITOS", grupo="1", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="17:30", dia="MARTES", tipo="T"),
    Clase(asig="MECANISMOS", grupo="1", aula="Aula 35-A2", hora_inicio="17:30", hora_fin="18:30", dia="MARTES", tipo="T"),
    Clase(asig="FLUIDOMEC.", grupo="101", aula="Aula Inf. 2B", hora_inicio="18:30", hora_fin="20:30", dia="MARTES", tipo="P"),
    Clase(asig="MECANISMOS", grupo="102", aula="Aula 35-A2", hora_inicio="14:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="MECANISMOS", grupo="1", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="17:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="AUTMOATISMOS", grupo="1", aula="Aula 35-A2", hora_inicio="17:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FLUIDOMEC.", grupo="102", aula="Aula Inf. 1B", hora_inicio="18:30", hora_fin="20:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AUTOMATISMOS", grupo="101", aula="Lab. Automática 1", hora_inicio="14:30", hora_fin="16:30", dia="JUEVES", tipo="P"),
    Clase(asig="ELECTRONICA", grupo="1", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="17:30", dia="JUEVES", tipo="T"),
    Clase(asig="ELECTRONICA", grupo="1", aula="Aula 35-A2", hora_inicio="17:30", hora_fin="18:30", dia="JUEVES", tipo="T"),
    Clase(asig="FLUIDOMEC.", grupo="101", aula="Aula Inf. 1B", hora_inicio="14:30", hora_fin="16:30", dia="VIERNES", tipo="P"),
    Clase(asig="ELECTRONICA", grupo="102", aula="Lab. Electrónica 1", hora_inicio="14:30", hora_fin="16:30", dia="VIERNES", tipo="P"),
    Clase(asig="ELECTRONICA", grupo="101", aula="Lab. Electrónica 1", hora_inicio="16:30", hora_fin="18:30", dia="VIERNES", tipo="P"),
    Clase(asig="FLUIDOMEC.", grupo="102", aula="Aula Inf. 1B", hora_inicio="16:30", hora_fin="18:30", dia="VIERNES", tipo="P"),

    Clase(asig="MAQUINAS ELEC.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
    Clase(asig="MAQUINAS ELEC.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="REG. AUTOMAT.", grupo="101", aula="Lab. Automática 1", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="SIST. ELECTRON.", grupo="101", aula="Lab. Electrónica 1", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="ELECT. DIGITAL", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="ELECTR. DIGITAL", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="MAQUINAS ELEC.", grupo="101", aula="Lab. Eléctrica 2", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="MAQUINAS ELEC.", grupo="101", aula="46-A2", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="ELECT. ANALOG.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ELECT. ANALOG.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ELECT. DIGITAL", grupo="101", aula="Lab. Electrónica 1", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="SIST. ELECTRON.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="SIST. ELECTRON.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="REG. AUTOMAT.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="REG. AUTOMAT.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),
    Clase(asig="ELECT. ANALOG.", grupo="101", aula="Lab. Electrónica 1", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    
    Clase(asig="PROD. Y FABRIC.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
    Clase(asig="PROD. Y FABRIC.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="INSTR. ELECT", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="INSTR. ELECT", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="SIST. MICRO.", grupo="101", aula="Lab. Electrónica 1", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="PROD. Y FABRIC.", grupo="101", aula="Lab 22-A1", hora_inicio="12:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="PROD. Y FABRIC.", grupo="101", aula="Lab. Tecn. Mecánica", hora_inicio="12:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="SIST. MICRO.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="SIST. MICRO.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="CONTROL PROC.", grupo="101", aula="Lab. Automática 1", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ELECT. POTENCIA", grupo="101", aula="Lab Electrónica 1", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ELECT. POTENCIA", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="ELECT. POTENCIA", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="INSTR. ELECT.", grupo="101", aula="Lab Electrónica 1", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="CONTROL PROC.", grupo="1", aula="Aula 46-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="CONTROL PROC.", grupo="1", aula="Aula 46-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),

    Clase(asig="ELECTRON. IND.", grupo="1", aula="Aula 0", hora_inicio="12:30", hora_fin="13:30", dia="LUNES", tipo="T"),
    Clase(asig="ELECTRON. IND.", grupo="1", aula="Aula 0", hora_inicio="13:30", hora_fin="14:30", dia="LUNES", tipo="T"),
    Clase(asig="DAO", grupo="1", aula="Aula 53-A2 (CAD)", hora_inicio="08:30", hora_fin="12:30", dia="MARTES", tipo="T"),
    Clase(asig="PREV. RIESGOS", grupo="1", aula="Aula 0", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="T"),
    Clase(asig="PREV. RIESGOS", grupo="1", aula="Aula 0", hora_inicio="13:30", hora_fin="14:30", dia="MARTES", tipo="T"),
    Clase(asig="INTEG S.E.", grupo="1", aula="Aula 0", hora_inicio="12:30", hora_fin="13:30", dia="JUEVES", tipo="T"),
    Clase(asig="INTEG.S.E.", grupo="1", aula="Aula 0", hora_inicio="13:30", hora_fin="14:30", dia="JUEVES", tipo="T"),
    Clase(asig="ELECTRON. IND.", grupo="101", aula="Aula 0", hora_inicio="12:30", hora_fin="14:30", dia="VIERNES", tipo="P"),

    Clase(asig="INSTAL. ELEC.", grupo="1", aula="Aula 42-A2", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="T"),
    Clase(asig="OFICINA", grupo="1", aula="Aula 42-A2", hora_inicio="16:30", hora_fin="17:30", dia="LUNES", tipo="T"),
    Clase(asig="INFIND", grupo="101", aula="Lab Automática 2", hora_inicio="17:30", hora_fin="19:30", dia="LUNES", tipo="P"),
    Clase(asig="INSTAL. ELEC.", grupo="101", aula="Aula Inf. 1B", hora_inicio="14:30", hora_fin="16:30", dia="MARTES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="101", aula="Lab. Fisica", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="INFIND", grupo="1", aula="Aula 42-A2", hora_inicio="18:30", hora_fin="19:30", dia="MARTES", tipo="T"),
    Clase(asig="INFIND", grupo="1", aula="Aula 42-A2", hora_inicio="19:30", hora_fin="20:30", dia="MARTES", tipo="T"),
    Clase(asig="PREV.", grupo="101", aula="Aula 0", hora_inicio="14:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="1", aula="Aula 42-A2", hora_inicio="18:30", hora_fin="19:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="RENOVABLES", grupo="1", aula="Aula 42-A2", hora_inicio="19:30", hora_fin="20:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="OFICINA", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="14:30", hora_fin="17:30", dia="JUEVES", tipo="P"),
    Clase(asig="INST SOLARES", grupo="101", aula="Aula 0", hora_inicio="18:30", hora_fin="19:30", dia="JUEVES", tipo="P"),
    Clase(asig="INST SOLARES", grupo="101", aula="Aula 0", hora_inicio="19:30", hora_fin="20:30", dia="JUEVES", tipo="P"),
    Clase(asig="INTEG S.E.", grupo="101", aula="Aula 0", hora_inicio="14:30", hora_fin="16:30", dia="VIERNES", tipo="P"),
    Clase(asig="INST SOLARES", grupo="1", aula="Aula 44-A2", hora_inicio="18:30", hora_fin="19:30", dia="VIERNES", tipo="T"),
    Clase(asig="INST SOLARES", grupo="1", aula="Aula 44-A2", hora_inicio="19:30", hora_fin="20:30", dia="VIERNES", tipo="T"),

    Clase(asig="ROBOTICA", grupo="1", aula="Aula 46-A2", hora_inicio="14:30", hora_fin="15:30", dia="LUNES", tipo="T"),
    Clase(asig="AUTIND", grupo="1", aula="Aula 46-A2", hora_inicio="15:30", hora_fin="16:30", dia="LUNES", tipo="T"),
    Clase(asig="ROBOTICA", grupo="101", aula="Lab Automática 1", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="ROBOTICA", grupo="1", aula="Aula 46-A2", hora_inicio="14:30", hora_fin="15:30", dia="MARTES", tipo="T"),
    Clase(asig="AUTIND", grupo="1", aula="Aula 46-A2", hora_inicio="15:30", hora_fin="16:30", dia="MARTES", tipo="T"),
    Clase(asig="AUTIND", grupo="101", aula="Lab Automática 2", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 salida_esperada_gieia = [
# ----> 2     Clase(asig="INFORMATICA", grupo="1", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
#       3     Clase(asig="FÍSICA I", grupo="1", aula="Aula 35-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
#       4     Clase(asig="FÍSICA I", grupo="101", aula="Lab. Física", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
#       5     Clase(asig="FÍSICA I", grupo="101", aula="Aula 42-A2", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
#       6     Clase(asig="CALCULO", grupo="102", aula="Aula Inf. 1B", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
# ...

# %%
salida_esperada_gim = [
    Clase(asig="EXPRESION GRAFICA", grupo="101", aula="Aula 53-A2 (CAD)", hora_inicio="08:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="101", aula="41-A2 (Tab)", hora_inicio="08:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="QUIMICA", grupo="102", aula="Lab. Química", hora_inicio="09:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="103", aula="Aula 55-A2 (CAD)", hora_inicio="08:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="103", aula="41-A2 (Tab)", hora_inicio="08:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="104", aula="Aula 34-A2", hora_inicio="09:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="104", aula="Aula 52-A2", hora_inicio="09:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Lab. Química", hora_inicio="11:30", hora_fin="13:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="102", aula="Aula 53-A2 (CAD)", hora_inicio="11:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="102", aula="41-A2 (Tab)", hora_inicio="11:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="103", aula="Aula 34-A2", hora_inicio="11:30", hora_fin="13:30", dia="LUNES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="103", aula="Aula 55-A2", hora_inicio="11:30", hora_fin="13:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="104", aula="Aula 55-A2 (CAD)", hora_inicio="11:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="EXPRESION GRAFICA", grupo="104", aula="41-A2 (Tab)", hora_inicio="11:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA I", grupo="103", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA I", grupo="103", aula="Aula 31-A2", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="QUIMICA", grupo="104", aula="Lab. Química", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="CALCULO", grupo="105", aula="Aula 51-A2 (Inf.)", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="T"),
    Clase(asig="FISICA I", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="GRUPO_TEORICO"),
    Clase(asig="EXP. GRAF. I", grupo="1", aula="Aula 51-A1", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="T"),
    Clase(asig="FISICA I", grupo="103", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA I", grupo="103", aula="Aula 31-A2", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="104", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="104", aula="Aula 52-A2", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FISICA I", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FISICA I", grupo="105", aula="Lab. Fisica", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA I", grupo="105", aula="Aula 31-A2", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="CALCULO", grupo="101", aula="Aula 51-A2 (Inf.)", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="FISICA I", grupo="102", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="FISICA I", grupo="102", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="QUIMICA", grupo="103", aula="Lab. Química", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="T"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="JUEVES", tipo="T"),
    Clase(asig="FISICA I", grupo="104", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="FISICA I", grupo="104", aula="Aula 31-A2", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="VIERNES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="VIERNES", tipo="T"),

    Clase(asig="CALCULO", grupo="102", aula="Aula 51-A2 (Inf.)", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="105", aula="Aula 52-A2 (Inf.)", hora_inicio="15:30", hora_fin="17:30", dia="MARTES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 52-A2 (Inf.)", hora_inicio="15:30", hora_fin="17:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="32-A2", hora_inicio="15:30", hora_fin="17:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="CALCULO", grupo="103", aula="Aula 51-A2 (Inf.)", hora_inicio="17:30", hora_fin="19:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="CALCULO", grupo="104", aula="Aula 51-A2 (Inf.)", hora_inicio="15:30", hora_fin="17:30", dia="JUEVES", tipo="P"),

    Clase(asig="INFORMATICA", grupo="101", aula="Lab 46-A1", hora_inicio="08:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA II", grupo="103", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA II", grupo="103", aula="Aula 31-A2", hora_inicio="08:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="MATERIALES", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="T"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="T"),
    Clase(asig="FISICA II", grupo="102", aula="Lab. Fisica", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA II", grupo="102", aula="Aula 31-A2", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="104", aula="Lab 46-A1", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Aula 31-A2", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="T"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="T"),
    Clase(asig="AMP. CALC.", grupo="101", aula="Aula 32-A1 (Inf.)", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AMP. CALC.", grupo="101", aula="Aula 42-A2", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA II", grupo="104", aula="Lab. Fisica", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA II", grupo="104", aula="Aula 36-A2", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="MATERIALES", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="AMP. CALC.", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="AMP. CALC.", grupo="104", aula="Aula 52-A2 (Inf.)", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AMP. CALC.", grupo="104", aula="Aula 42-A2", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="MATERIALES", grupo="102", aula="Lab. Materiales", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="103", aula="Aula 54-A1", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="AMP. CALC.", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="JUEVES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="102", aula="Aula 51-A1", hora_inicio="12:30", hora_fin="14:30", dia="JUEVES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="101", aula="Aula 54-A1", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="102", aula="Lab 46-A1", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALC.", grupo="104", aula="Aula 32-A1 (Inf.)", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALC.", grupo="104", aula="Aula 42-A2", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 51-A1", hora_inicio="10:30", hora_fin="11:30", dia="VIERNES", tipo="T"),
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 51-A1", hora_inicio="11:30", hora_fin="12:30", dia="VIERNES", tipo="T"),
    Clase(asig="AMP. CALC.", grupo="102", aula="Aula 32-A1 (Inf.)", hora_inicio="12:30", hora_fin="14:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALC.", grupo="102", aula="Aula 42-A2", hora_inicio="12:30", hora_fin="14:30", dia="VIERNES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="103", aula="Lab 46-A1", hora_inicio="12:30", hora_fin="14:30", dia="VIERNES", tipo="P"),
    
    Clase(asig="MATERIALES", grupo="103", aula="Lab. Materiales", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="MATERIALES", grupo="101", aula="Lab. Materiales", hora_inicio="16:30", hora_fin="18:30", dia="JUEVES", tipo="P"),

    Clase(asig="ERMAT I", grupo="1", aula="Aula 51-A1", hora_inicio="14:30", hora_fin="15:30", dia="LUNES", tipo="T"),
    Clase(asig="TERMICA I", grupo="1", aula="Aula 51-A1", hora_inicio="15:30", hora_fin="16:30", dia="LUNES", tipo="T"),
    Clase(asig="ERMAT I", grupo="101", aula="Aula 46-A2", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="TERMICA I", grupo="102", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="TERMICA I", grupo="102", aula="Aula Inf. 1B", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="103", aula="Lab. I. Eléctrica 1", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="ERMAT I", grupo="1", aula="Aula 51-A1", hora_inicio="14:30", hora_fin="15:30", dia="MARTES", tipo="T"),
    Clase(asig="ING. ELECTRICA", grupo="1", aula="Aula 51-A1", hora_inicio="15:30", hora_fin="16:30", dia="MARTES", tipo="T"),
    Clase(asig="ING. ELECTRICA", grupo="101", aula="Lab. I. Eléctrica 1", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="ERMAT I", grupo="102", aula="Aula 46-A2", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="AUTOMATISMOS", grupo="103", aula="Lab. Automatica 2", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="TERMICA I", grupo="1", aula="Aula 51-A1", hora_inicio="14:30", hora_fin="15:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FLUIDOMECANICA", grupo="1", aula="Aula 51-A1", hora_inicio="15:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="TERMICA I", grupo="101", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="TERMICA I", grupo="101", aula="Aula Inf. 1B", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FLUIDOMECANICA", grupo="102", aula="Aula 33-A2", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ERMAT I", grupo="103", aula="Aula 42-A2", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FLUIDOMECANICA", grupo="102", aula="Aula 33-A2", hora_inicio="18:30", hora_fin="20:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="1", aula="Aula 51-A1", hora_inicio="14:30", hora_fin="15:30", dia="JUEVES", tipo="T"),
    Clase(asig="AUTOMATISMOS", grupo="1", aula="Aula 51-A1", hora_inicio="15:30", hora_fin="16:30", dia="JUEVES", tipo="T"),
    Clase(asig="AUTOMATISMOS", grupo="101", aula="Lab. Automatica 2", hora_inicio="16:30", hora_fin="18:30", dia="JUEVES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="102", aula="Lab. I. Eléctrica 1", hora_inicio="16:30", hora_fin="18:30", dia="JUEVES", tipo="P"),
    Clase(asig="TERMICA I", grupo="103", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="18:30", dia="JUEVES", tipo="P"),
    Clase(asig="TERMICA I", grupo="103", aula="Aula Inf. 1B", hora_inicio="16:30", hora_fin="18:30", dia="JUEVES", tipo="P"),
    Clase(asig="AUTOMATISMOS", grupo="1", aula="Aula 51-A1", hora_inicio="14:30", hora_fin="15:30", dia="VIERNES", tipo="T"),
    Clase(asig="FLUIDOMECANICA", grupo="1", aula="Aula 51-A1", hora_inicio="15:30", hora_fin="16:30", dia="VIERNES", tipo="T"),
    Clase(asig="FLUIDOMECANICA", grupo="101", aula="Aula 33-A2", hora_inicio="16:30", hora_fin="18:30", dia="VIERNES", tipo="P"),
    Clase(asig="AUTOMATISMOS", grupo="102", aula="Lab. Automatica 2", hora_inicio="16:30", hora_fin="18:30", dia="VIERNES", tipo="P"),
    
    Clase(asig="ELECTRONICA", grupo="1", aula="Aula 52-A1", hora_inicio="14:30", hora_fin="15:30", dia="LUNES", tipo="T"),
    Clase(asig="E.C.N.", grupo="1", aula="Aula 52-A1", hora_inicio="15:30", hora_fin="16:30", dia="LUNES", tipo="T"),
    Clase(asig="E.C.N.", grupo="101", aula="Aula 51-A1", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="MECANISMOS", grupo="102", aula="Aula 46-A2", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="ELECTRONICA", grupo="103", aula="Lab. Electrónica 1", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="P"),
    Clase(asig="MECANISMOS", grupo="101", aula="Aula 46-A2", hora_inicio="18:30", hora_fin="20:30", dia="LUNES", tipo="P"),
    Clase(asig="E.C.N.", grupo="102", aula="Aula 51-A2 (Inf.)", hora_inicio="18:30", hora_fin="20:30", dia="LUNES", tipo="P"),
    Clase(asig="E.C.N.", grupo="103", aula="Aula Inf. 2B", hora_inicio="18:30", hora_fin="20:30", dia="LUNES", tipo="P"),
    Clase(asig="MECANISMOS", grupo="1", aula="Aula 52-A1", hora_inicio="14:30", hora_fin="15:30", dia="MARTES", tipo="T"),
    Clase(asig="ORGANIZACION", grupo="1", aula="Aula 52-A1", hora_inicio="15:30", hora_fin="16:30", dia="MARTES", tipo="T"),
    Clase(asig="ORGANIZACION", grupo="101", aula="Lab 22-A1", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="102", aula="Aula 55-A2 (CAD)", hora_inicio="16:30", hora_fin="19:30", dia="MARTES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="102", aula="41-A2 (Tab)", hora_inicio="16:30", hora_fin="19:30", dia="MARTES", tipo="P"),
    Clase(asig="MECANISMOS", grupo="103", aula="Aula 46-A2", hora_inicio="16:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="ELECTRONICA", grupo="101", aula="Lab. Electrónica 1", hora_inicio="18:30", hora_fin="20:30", dia="MARTES", tipo="P"),
    Clase(asig="ORGANIZACION", grupo="103", aula="Lab 22-A1", hora_inicio="18:30", hora_fin="20:30", dia="MARTES", tipo="P"),
    Clase(asig="E.C.N.", grupo="1", aula="Aula 52-A1", hora_inicio="14:30", hora_fin="15:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ORGANIZACION", grupo="1", aula="Aula 52-A1", hora_inicio="15:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="EXP. GRAFICA II", grupo="102", aula="Aula 55-A2 (CAD)", hora_inicio="16:30", hora_fin="19:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="102", aula="41-A2 (Tab)", hora_inicio="16:30", hora_fin="19:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ORGANIZACION", grupo="102", aula="Lab 22-A1", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="1", aula="Aula 41-A2", hora_inicio="14:30", hora_fin="15:30", dia="JUEVES", tipo="T"),
    Clase(asig="ORGANIZACION", grupo="1", aula="Aula 52-A1", hora_inicio="15:30", hora_fin="16:30", dia="JUEVES", tipo="T"),
    Clase(asig="MECANISMOS", grupo="1", aula="Aula 52-A1", hora_inicio="16:30", hora_fin="17:30", dia="JUEVES", tipo="T"),
    Clase(asig="ELECTRONICA", grupo="102", aula="Lab. Electrónica 1", hora_inicio="17:30", hora_fin="19:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="103", aula="Aula 55-A2 (CAD)", hora_inicio="17:30", hora_fin="20:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="103", aula="41-A2 (Tab)", hora_inicio="17:30", hora_fin="20:30", dia="JUEVES", tipo="P"),

    Clase(asig="RESISTENCIA II", grupo="1", aula="Aula 36-A2", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
    Clase(asig="RESISTENCIA II", grupo="1", aula="Aula 36-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="MECANISMOS II", grupo="101", aula="Lab Mecanismos", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="MECANISMOS II", grupo="101", aula="36-A2", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="PROD. Y FABR.", grupo="102", aula="Aula Inf. 2B", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="PROD. Y FABR.", grupo="102", aula="Lab. Tecn. Mecánica", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="PROD. Y FABR.", grupo="101", aula="Aula Inf. 2B", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="PROD. Y FABR.", grupo="101", aula="31-A2", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="ING. GRAFICA", grupo="1", aula="Aula 55-A2 (CAD)", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="I. MATERIALES", grupo="1", aula="Aula 36-A2", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="ING. GAFRICA", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="MECANISMOS II", grupo="102", aula="Lab Mecanismos", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="MECANISMOS II", grupo="102", aula="36-A2", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="MECANISMOS II", grupo="1", aula="Aula 36-A2", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="MECANISMOS II", grupo="1", aula="Aula 36-A2", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="RESISTENCIA II", grupo="101", aula="Aula 36-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="RESISTENCIA II", grupo="101", aula="Lab. MMC", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ING. GAFRICA", grupo="102", aula="Aula 55-A2 (CAD)", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="PROD. Y FABR.", grupo="1", aula="Aula 36-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="PROD. Y FABR.", grupo="1", aula="Aula 36-A2", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="I. MATERIALES", grupo="101", aula="Lab. Materiales", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="RESISTENCIA II", grupo="101", aula="Aula 36-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="RESISTENCIA II", grupo="101", aula="Lab. MMC", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="I. MATERIALES", grupo="1", aula="Aula 36-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),
    
    Clase(asig="MAQ. HIDRAUL.", grupo="101", aula="Aula 44-A2", hora_inicio="08:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="ESTRUCTURAS I", grupo="102", aula="Aula 42-A2", hora_inicio="08:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="MAQ. HIDRAUL.", grupo="1", aula="Aula 52-A1", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="T"),
    Clase(asig="TECN. MEC. I", grupo="1", aula="Aula 52-A1", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="T"),
    Clase(asig="TECN. MEC. I", grupo="1", aula="Aula 52-A1", hora_inicio="12:30", hora_fin="13:30", dia="LUNES", tipo="T"),
    Clase(asig="TECN. MEC. I", grupo="101", aula="Lab. Tecn. Mecánica", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="TERMICA II", grupo="102", aula="Aula 42-A2", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="TERMICA II", grupo="102", aula="Aula Inf. 1B", hora_inicio="08:30", hora_fin="10:30", dia="MARTES", tipo="P"),
    Clase(asig="TERMICA II.", grupo="1", aula="Aula 52-A1", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="T"),
    Clase(asig="ESTRUCTURAS I", grupo="1", aula="Aula 52-A1", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="T"),
    Clase(asig="DISEÑO MAQ. I", grupo="1", aula="Aula 52-A1", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="T"),
    Clase(asig="DISEÑO MAQ. I", grupo="1", aula="Aula 52-A1", hora_inicio="13:30", hora_fin="14:30", dia="MARTES", tipo="T"),
    Clase(asig="TERMICA II", grupo="101", aula="Aula 34-A2", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="TERMICA II", grupo="101", aula="Aula Inf. 1B", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="TECN. MEC. I", grupo="102", aula="Lab. Tecn. Mecánica", hora_inicio="08:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="TERMICA II.", grupo="1", aula="Aula 52-A1", hora_inicio="10:30", hora_fin="11:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="DISEÑO MAQ. I", grupo="101", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="MAQ. HIDRAUL.", grupo="102", aula="Aula 44-A2", hora_inicio="08:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="MAQ. HIDRAUL.", grupo="1", aula="Aula 52-A1", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="T"),
    Clase(asig="ESTRUCTURAS I", grupo="101", aula="Aula 44-A2", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="DISEÑO MAQ. I", grupo="102", aula="Aula 35-A2", hora_inicio="08:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="ESTRUCTURAS I", grupo="1", aula="Aula 52-A1", hora_inicio="10:30", hora_fin="11:30", dia="VIERNES", tipo="T"),

    Clase(asig="OFICINA TECNICA", grupo="1", aula="Aula 54-A1", hora_inicio="14:30", hora_fin="15:30", dia="LUNES", tipo="T"),
    Clase(asig="MAQ. TERMICAS", grupo="1", aula="Aula 54-A1", hora_inicio="15:30", hora_fin="16:30", dia="LUNES", tipo="T"),
    Clase(asig="MAQ. TERMICAS", grupo="1", aula="Aula 54-A1", hora_inicio="16:30", hora_fin="17:30", dia="LUNES", tipo="T"),
    Clase(asig="OFICINA TECNICA", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="17:30", hora_fin="20:30", dia="LUNES", tipo="P"),
    Clase(asig="DISEÑO MAQ. II", grupo="1", aula="Aula 54-A1", hora_inicio="15:30", hora_fin="16:30", dia="MARTES", tipo="T"),
    Clase(asig="DISEÑO MAQ. II", grupo="1", aula="Aula 54-A1", hora_inicio="16:30", hora_fin="17:30", dia="MARTES", tipo="T"),
    Clase(asig="ESTRUCTURAS II", grupo="101", aula="Aula 54-A1", hora_inicio="17:30", hora_fin="19:30", dia="MARTES", tipo="P"),
    Clase(asig="INSTALACIONES I", grupo="1", aula="Lab. MMC", hora_inicio="14:30", hora_fin="15:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="INSTALACIONES I", grupo="1", aula="Lab. MMC", hora_inicio="15:30", hora_fin="16:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ESTRUCTURAS II", grupo="101", aula="Lab. Ing. Energetica 1", hora_inicio="16:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="DISEÑO MAQ. II", grupo="101", aula="Aula 54-A1", hora_inicio="18:30", hora_fin="20:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ESTRUCTURAS II", grupo="1", aula="Aula 54-A1", hora_inicio="14:30", hora_fin="15:30", dia="JUEVES", tipo="T"),
    Clase(asig="ESTRUCTURAS II", grupo="1", aula="Aula 54-A1", hora_inicio="15:30", hora_fin="16:30", dia="JUEVES", tipo="T"),
    Clase(asig="INSTALACIONES I", grupo="101", aula="Lab. MMC", hora_inicio="16:30", hora_fin="18:30", dia="JUEVES", tipo="P"),

    Clase(asig="RENOV. Y M.AMB", grupo="1", aula="Aula 36-A2", hora_inicio="16:30", hora_fin="17:30", dia="LUNES", tipo="T"),
    Clase(asig="RENOV. Y M.AMB", grupo="1", aula="Aula 36-A2", hora_inicio="17:30", hora_fin="18:30", dia="LUNES", tipo="T"),
    Clase(asig="TECN. MEC. II", grupo="101", aula="Aula 0", hora_inicio="18:30", hora_fin="19:30", dia="LUNES", tipo="P"),
    Clase(asig="TECN. MEC. II", grupo="101", aula="Aula 0", hora_inicio="19:30", hora_fin="20:30", dia="LUNES", tipo="P"),
    Clase(asig="SIMULACION", grupo="101", aula="Aula Inf. 2B", hora_inicio="16:30", hora_fin="17:30", dia="MARTES", tipo="P"),
    Clase(asig="SIMULACION", grupo="101", aula="Aula Inf. 2B", hora_inicio="17:30", hora_fin="18:30", dia="MARTES", tipo="P"),
    Clase(asig="INGLES", grupo="1", aula="Aula 42-A2", hora_inicio="18:30", hora_fin="19:30", dia="MARTES", tipo="T"),
    Clase(asig="INGLES", grupo="1", aula="Aula 42-A2", hora_inicio="19:30", hora_fin="20:30", dia="MARTES", tipo="T"),
    Clase(asig="RENOV. Y M.AMB", grupo="101", aula="Lab. Quimica", hora_inicio="16:30", hora_fin="17:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="RENOV. Y M.AMB", grupo="101", aula="Lab. Fisica", hora_inicio="16:30", hora_fin="17:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="RENOV. Y M.AMB", grupo="101", aula="Lab. Quimica", hora_inicio="17:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="RENOV. Y M.AMB", grupo="101", aula="Lab. Fisica", hora_inicio="17:30", hora_fin="18:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="SIMULACION", grupo="1", aula="Aula Inf. 2B", hora_inicio="18:30", hora_fin="19:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="SIMULACION", grupo="1", aula="Aula Inf. 2B", hora_inicio="19:30", hora_fin="20:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="EQUILIBRADO", grupo="1", aula="Aula 0", hora_inicio="14:30", hora_fin="15:30", dia="JUEVES", tipo="T"),
    Clase(asig="EQUILIBRADO", grupo="1", aula="Aula 0", hora_inicio="15:30", hora_fin="16:30", dia="JUEVES", tipo="T"),
    Clase(asig="INGLES", grupo="101", aula="Aula 42-A2", hora_inicio="16:30", hora_fin="17:30", dia="JUEVES", tipo="P"),
    Clase(asig="INGLES", grupo="101", aula="Aula 42-A2", hora_inicio="17:30", hora_fin="18:30", dia="JUEVES", tipo="P"),
    Clase(asig="TECN. MEC. II", grupo="1", aula="Aula 0", hora_inicio="18:30", hora_fin="19:30", dia="JUEVES", tipo="T"),
    Clase(asig="TECN. MEC. II", grupo="1", aula="Aula 0", hora_inicio="19:30", hora_fin="20:30", dia="JUEVES", tipo="T"),
    Clase(asig="EQUILIBRADO", grupo="101", aula="Aula 0", hora_inicio="18:30", hora_fin="19:30", dia="VIERNES", tipo="P"),
    Clase(asig="EQUILIBRADO", grupo="101", aula="Aula 0", hora_inicio="19:30", hora_fin="20:30", dia="VIERNES", tipo="P"),
    
]

# %%
salida_esperada_gioi = [
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="T"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="INFORMATICA", grupo="101", aula="Lab 46-A1", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="102", aula="Aula 51-A2 (Inf.)", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="101", aula="Aula 51-A2 (Inf.)", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="102", aula="Lab 46-A1", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="FISICA I", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="QUIMICA", grupo="101", aula="Lab. Química", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA I", grupo="102", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA I", grupo="102", aula="Aula 31-A2", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="CALCULO", grupo="103", aula="Aula 51-A2 (Inf.)", hora_inicio="10:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="QUIMICA", grupo="102", aula="Lab. Química", hora_inicio="12:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FISICA I", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FISICA I", grupo="101", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA I", grupo="101", aula="Aula 31-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="DRAWING I", grupo="80", aula="Aula 53-A2 (CAD)", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="T"),
    Clase(asig="DRAWING I", grupo="801", aula="Aula 53-A2 (CAD)", hora_inicio="11:30", hora_fin="14:30", dia="JUEVES", tipo="P"),
    Clase(asig="DRAWING I", grupo="801", aula="41-A2 (Tab)", hora_inicio="11:30", hora_fin="14:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="1", aula="Aula 41-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="Aula 53-A2 (CAD)", hora_inicio="09:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="41-A2 (Tab)", hora_inicio="09:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="103", aula="Aula 55-A2 (CAD)", hora_inicio="09:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="103", aula="41-A2 (Tab)", hora_inicio="09:30", hora_fin="12:30", dia="VIERNES", tipo="P"),

    Clase(asig="ENG. MATERIALS", grupo="801", aula="Lab. Materiales", hora_inicio="08:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Aula 34-A2", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="103", aula="Aula Inf. 2B", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="103", aula="Aula 42-A2", hora_inicio="10:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="101", aula="Aula Inf. 2B", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="101", aula="Aula 42-A2", hora_inicio="12:30", hora_fin="14:30", dia="LUNES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 31-A2", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 31-A2", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="T"),
    Clase(asig="AMP. CALCULO", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 33-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="32-A1 (Inf.)", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="102", aula="Aula 51-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="102", aula="Aula 31-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA II", grupo="103", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="FISICA II", grupo="103", aula="Aula 34-A2", hora_inicio="10:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="102", aula="Aula 34-A2", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="102", aula="32-A1 (Inf.)", hora_inicio="12:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="AMP. CALCULO", grupo="101", aula="Aula 51-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="101", aula="Aula 31-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="FISICA II", grupo="102", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="FISICA II", grupo="1002", aula="Aula 34-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 42-A2", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="32-A1 (Inf.)", hora_inicio="10:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="MATERIALES", grupo="1", aula="Aula 52-A1", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="MATERIALES", grupo="1", aula="Aula 52-A1", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),
    Clase(asig="ENG. MATERIALS", grupo="80", aula="Aula 32-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="ENG. MATERIALS", grupo="1", aula="Aula 32-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="T"),
    Clase(asig="AMP. CALCULO", grupo="103", aula="Aula 51-A2", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="103", aula="Aula 31-A2", hora_inicio="10:30", hora_fin="12:30", dia="VIERNES", tipo="P"),

    Clase(asig="FLUIDOMECANICA", grupo="101", aula="Aula 33-A2", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="FLUIDOMECANICA", grupo="101", aula="Aula 22-A1", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="102", aula="Lab. Ing. Eléctrica", hora_inicio="14:30", hora_fin="16:30", dia="LUNES", tipo="P"),
    Clase(asig="ELASTICITY", grupo="80", aula="Aula 32-A2", hora_inicio="14:30", hora_fin="15:30", dia="LUNES", tipo="T"),
    Clase(asig="ELASTICITY", grupo="80", aula="Aula 32-A2", hora_inicio="15:30", hora_fin="16:30", dia="LUNES", tipo="T"),
    Clase(asig="AUTOMATISMOS", grupo="1", aula="Aula 52-A1", hora_inicio="16:30", hora_fin="18:30", dia="LUNES", tipo="T"),
]

# %%
salida_esperada_d_gim_gieia = [
    Clase(asig="FISICA I", grupo="1", aula="Aula 33-A2", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="T"),
    Clase(asig="FISICA I", grupo="1", aula="Aula 33-A2", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="T"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 33-A2", hora_inicio="12:30", hora_fin="13:30", dia="LUNES", tipo="T"),
    Clase(asig="CALCULO", grupo="1", aula="Aula 33-A2", hora_inicio="13:30", hora_fin="14:30", dia="LUNES", tipo="T"),
    Clase(asig="CALCULO", grupo="101", aula="Aula 33-A2", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="101", aula="Aula 52-A2 (Inf.)", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="101", aula="Aula 33-A2", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="CALCULO", grupo="101", aula="Aula 52-A2 (Inf.)", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 33-A2", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="T"),
    Clase(asig="QUIMICA", grupo="1", aula="Aula 33-A2", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="T"),
    Clase(asig="FISICA I", grupo="101", aula="Lab. Fisica", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA I", grupo="101", aula="Aula 33-A2", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA I", grupo="101", aula="Lab. Fisica", hora_inicio="13:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA I", grupo="101", aula="Aula 33-A2", hora_inicio="13:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Lab. Química", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Aula 33-A2", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Lab. Química", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="QUIMICA", grupo="101", aula="Aula 33-A2", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 33-A2", hora_inicio="10:30", hora_fin="11:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ALGEBRA", grupo="1", aula="Aula 33-A2", hora_inicio="11:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="EXP. GRAFICA I", grupo="1", aula="Aula 55-A2 (CAD)", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="EXP. GRAFICA I", grupo="1", aula="41-A2 (Tab)", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="41-A2 (Tab)", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="41-A2 (Tab)", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="11:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="EXP. GRAFICA I", grupo="101", aula="41-A2 (Tab)", hora_inicio="11:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 51-A2 (Inf.)", hora_inicio="12:30", hora_fin="13:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="33-A2", hora_inicio="12:30", hora_fin="13:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="Aula 51-A2 (Inf.)", hora_inicio="13:30", hora_fin="14:30", dia="JUEVES", tipo="P"),
    Clase(asig="ALGEBRA", grupo="101", aula="33-A2", hora_inicio="13:30", hora_fin="14:30", dia="JUEVES", tipo="P"),

    Clase(asig="ECONOMIA", grupo="101", aula="Aula 21-A1", hora_inicio="08:30", hora_fin="09:30", dia="LUNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="101", aula="Aula 21-A1", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="101", aula="41-A2 (Tab)", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="101", aula="41-A2 (Tab)", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="101", aula="Aula 55-A2 (CAD)", hora_inicio="12:30", hora_fin="13:30", dia="LUNES", tipo="P"),
    Clase(asig="EXP. GRAFICA II", grupo="101", aula="41-A2 (Tab)", hora_inicio="12:30", hora_fin="13:30", dia="LUNES", tipo="P"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 21-A1", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="ECONOMIA", grupo="1", aula="Aula 21-A1", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="FISICA II", grupo="101", aula="Lab. Fisica", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Aula 33-A2", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Lab. Fisica", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA II", grupo="101", aula="Aula 33-A2", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="P"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 33-A2", hora_inicio="08:30", hora_fin="09:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="FISICA II", grupo="1", aula="Aula 33-A2", hora_inicio="09:30", hora_fin="10:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="INFORMATICA", grupo="101", aula="Lab 46-A1", hora_inicio="10:30", hora_fin="11:30", dia="MIÉRCÓLES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="101", aula="Lab 46-A1", hora_inicio="11:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="1", aula="Aula 33-A2", hora_inicio="12:30", hora_fin="13:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="AMP. CALCULO", grupo="1", aula="Aula 33-A2", hora_inicio="13:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="EXP. GRAFICA II", grupo="1", aula="Aula 33-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 33-A2", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="T"),
    Clase(asig="CIENCIA DE MATERIALES", grupo="101", aula="Lab. Materiales", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="P"),
    Clase(asig="CIENCIA DE MATERIALES", grupo="101", aula="Lab. Materiales", hora_inicio="11:30", hora_fin="12:30", dia="JUEVES", tipo="P"),
    Clase(asig="INFORMATICA", grupo="1", aula="Aula 33-A2", hora_inicio="12:30", hora_fin="13:30", dia="JUEVES", tipo="T"),
    Clase(asig="AMP. CALCULO", grupo="101", aula="Aula 52-A2 (Inf.)", hora_inicio="10:30", hora_fin="11:30", dia="VIERNES", tipo="P"),
    Clase(asig="AMP. CALCULO", grupo="101", aula="Aula 52-A2 (Inf.)", hora_inicio="11:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="CIENCIA DE MATERIALES", grupo="1", aula="Aula 33-A2", hora_inicio="12:30", hora_fin="13:30", dia="VIERNES", tipo="T"),
    Clase(asig="CIENCIA DE MATERIALES", grupo="1", aula="Aula 33-A2", hora_inicio="13:30", hora_fin="14:30", dia="VIERNES", tipo="T"),

    Clase(asig="PRODUCCION", grupo="1", aula="Aula 44-A2", hora_inicio="09:30", hora_fin="10:30", dia="LUNES", tipo="T"),
    Clase(asig="PRODUCCION", grupo="101", aula="Lab. 24-A1", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="PRODUCCION", grupo="101", aula="44-A2", hora_inicio="10:30", hora_fin="11:30", dia="LUNES", tipo="P"),
    Clase(asig="PRODUCCION", grupo="101", aula="Lab. 24-A1", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="PRODUCCION", grupo="101", aula="44-A2", hora_inicio="11:30", hora_fin="12:30", dia="LUNES", tipo="P"),
    Clase(asig="ERMAT I", grupo="1", aula="Aula 44-A2", hora_inicio="12:30", hora_fin="13:30", dia="LUNES", tipo="T"),
    Clase(asig="ING. TERMICA I", grupo="1", aula="Aula 44-A2", hora_inicio="13:30", hora_fin="14:30", dia="LUNES", tipo="T"),
    Clase(asig="ING. ELECTRICA", grupo="1", aula="Aula 44-A2", hora_inicio="08:30", hora_fin="09:30", dia="MARTES", tipo="T"),
    Clase(asig="PRODUCCION", grupo="1", aula="Aula 44-A2", hora_inicio="09:30", hora_fin="10:30", dia="MARTES", tipo="T"),
    Clase(asig="RENOVABLES", grupo="1", aula="Aula 44-A2", hora_inicio="10:30", hora_fin="11:30", dia="MARTES", tipo="T"),
    Clase(asig="ERMAT I", grupo="1", aula="Aula 44-A2", hora_inicio="11:30", hora_fin="12:30", dia="MARTES", tipo="T"),
    Clase(asig="ERMAT I", grupo="101", aula="44-A2", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="P"),
    Clase(asig="ERMAT I", grupo="101", aula="Lab. MMC", hora_inicio="12:30", hora_fin="13:30", dia="MARTES", tipo="P"),
    Clase(asig="ERMAT I", grupo="101", aula="44-A2", hora_inicio="13:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="ERMAT I", grupo="101", aula="Lab. MMC", hora_inicio="13:30", hora_fin="14:30", dia="MARTES", tipo="P"),
    Clase(asig="ING. TERMICA I", grupo="1", aula="Aula 44-A2", hora_inicio="11:30", hora_fin="12:30", dia="MIÉRCOLES", tipo="T"),
    Clase(asig="ING. TERMICA I", grupo="101", aula="Aula 44-A2", hora_inicio="12:30", hora_fin="13:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ING. TERMICA I", grupo="101", aula="Aula Inf 1B", hora_inicio="12:30", hora_fin="13:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ING. TERMICA I", grupo="101", aula="Aula 44-A2", hora_inicio="13:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ING. TERMICA I", grupo="101", aula="Aula Inf 1B", hora_inicio="13:30", hora_fin="14:30", dia="MIÉRCOLES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="1", aula="Aula 44-A2", hora_inicio="08:30", hora_fin="09:30", dia="JUEVES", tipo="T"),
    Clase(asig="ING. ELECTRICA", grupo="101", aula="Lab. Ing. Eléctrica", hora_inicio="09:30", hora_fin="10:30", dia="JUEVES", tipo="P"),
    Clase(asig="ING. ELECTRICA", grupo="101", aula="Lab. Ing. Eléctrica", hora_inicio="10:30", hora_fin="11:30", dia="JUEVES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="1", aula="Aula 44-A2", hora_inicio="08:30", hora_fin="09:30", dia="VIERNES", tipo="T"),
    Clase(asig="ERMAT I", grupo="101", aula="44-A2", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="ERMAT I", grupo="101", aula="Lab. MMC", hora_inicio="09:30", hora_fin="10:30", dia="VIERNES", tipo="P"),
    Clase(asig="ERMAT I", grupo="101", aula="44-A2", hora_inicio="10:30", hora_fin="11:30", dia="VIERNES", tipo="P"),
    Clase(asig="ERMAT I", grupo="101", aula="Lab. MMC", hora_inicio="10:30", hora_fin="11:30", dia="VIERNES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="101", aula="Lab. Química", hora_inicio="11:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="101", aula="Lab. Fisica", hora_inicio="11:30", hora_fin="12:30", dia="VIERNES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="101", aula="Lab. Química", hora_inicio="12:30", hora_fin="13:30", dia="VIERNES", tipo="P"),
    Clase(asig="RENOVABLES", grupo="101", aula="Lab. Fisica", hora_inicio="12:30", hora_fin="13:30", dia="VIERNES", tipo="P"),

    Clase(asig="E.C.N", grupo="1", aula="Aula 35-A2", hora_inicio="16:30", hora_fin="17:30", dia="MARTES", tipo="T"),
    Clase(asig="E.C.N", grupo="1", aula="Aula 35-A2", hora_inicio="17:30", hora_fin="18:30", dia="MARTES", tipo="T"),
    Clase(asig="E.C.N.", grupo="101", aula="Aula 51-A2 (Inf.)", hora_inicio="16:30", hora_fin="17:30", dia="JUEVES", tipo="P"),
    Clase(asig="E.C.N", grupo="101", aula="Aula 51-A2 (Inf.)", hora_inicio="17:30", hora_fin="18:30", dia="JUEVES", tipo="P"),

]
